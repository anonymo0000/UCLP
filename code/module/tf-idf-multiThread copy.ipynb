# %%
#       tfidf

#v  
path0_v = "/home/user/lh/PMA_lihang/mypaper/label_description/for_others/att_type0_v.txt"
path1_v = "/home/user/lh/PMA_lihang/mypaper/label_description/for_others/att_type1_v.txt"
path2_v = "/home/user/lh/PMA_lihang/mypaper/label_description/for_others/att_type2_v.txt"
path3_v = "/home/user/lh/PMA_lihang/mypaper/label_description/for_others/att_type3_v.txt"
path4_v = "/home/user/lh/PMA_lihang/mypaper/label_description/for_others/att_type4_v.txt"
path5_v = "/home/user/lh/PMA_lihang/mypaper/label_description/for_others/att_type5_v.txt"

path0_i = "/home/user/lh/PMA_lihang/mypaper/label_description/for_others/att_type0_i.txt"
path1_i = "/home/user/lh/PMA_lihang/mypaper/label_description/for_others/att_type1_i.txt"
path2_i = "/home/user/lh/PMA_lihang/mypaper/label_description/for_others/att_type2_i.txt"
path3_i = "/home/user/lh/PMA_lihang/mypaper/label_description/for_others/att_type3_i.txt"
path4_i = "/home/user/lh/PMA_lihang/mypaper/label_description/for_others/att_type4_i.txt"
path5_i = "/home/user/lh/PMA_lihang/mypaper/label_description/for_others/att_type5_i.txt"

path0_t = "/home/user/lh/PMA_lihang/mypaper/label_description/for_others/att_type0_t.txt"
path1_t = "/home/user/lh/PMA_lihang/mypaper/label_description/for_others/att_type1_t.txt"
path2_t = "/home/user/lh/PMA_lihang/mypaper/label_description/for_others/att_type2_t.txt"
path3_t = "/home/user/lh/PMA_lihang/mypaper/label_description/for_others/att_type3_t.txt"
path4_t = "/home/user/lh/PMA_lihang/mypaper/label_description/for_others/att_type4_t.txt"
path5_t = "/home/user/lh/PMA_lihang/mypaper/label_description/for_others/att_type5_t.txt"




f0_v = open(path0_v, 'r')
f1_v = open(path1_v, 'r')
f2_v = open(path2_v, 'r')
f3_v = open(path3_v, 'r')
f4_v = open(path4_v, 'r')
f5_v = open(path5_v, 'r')

f0_i = open(path0_i, 'r')
f1_i = open(path1_i, 'r')
f2_i = open(path2_i, 'r')
f3_i = open(path3_i, 'r')
f4_i = open(path4_i, 'r')
f5_i = open(path5_i, 'r')

f0_t = open(path0_t, 'r')
f1_t = open(path1_t, 'r')
f2_t = open(path2_t, 'r')
f3_t = open(path3_t, 'r')
f4_t = open(path4_t, 'r')
f5_t = open(path5_t, 'r')


lines0v = f0_v.readlines()
lines1v = f1_v.readlines()
lines2v = f2_v.readlines()
lines3v = f3_v.readlines()
lines4v = f4_v.readlines()
lines5v = f5_v.readlines()

lines0i = f0_i.readlines()
lines1i = f1_i.readlines()
lines2i = f2_i.readlines()
lines3i = f3_i.readlines()
lines4i = f4_i.readlines()
lines5i = f5_i.readlines()

lines0t = f0_t.readlines()
lines1t = f1_t.readlines()
lines2t = f2_t.readlines()
lines3t = f3_t.readlines()
lines4t = f4_t.readlines()
lines5t = f5_t.readlines()



v0 = ""
v1 = ""
v2 = ""
v3 = ""
v4 = ""
v5 = ""
for line in lines0v:
    v0 += line + " "
for line in lines1v:
    v1 += line + " "
for line in lines2v:
    v2 += line + " "
for line in lines3v:
    v3 += line + " "
for line in lines4v:
    v4 += line + " "
for line in lines5v:
    v5 += line + " "

i0 = ""
i1 = ""
i2 = ""
i3 = ""
i4 = ""
i5 = ""
for line in lines0i:
    i0 += line + " "
for line in lines1i:
    i1 += line + " "
for line in lines2i:
    i2 += line + " "
for line in lines3i:
    i3 += line + " "
for line in lines4i:
    i4 += line + " "
for line in lines5i:
    i5 += line + " "

t0 = ""
t1 = ""
t2 = ""
t3 = ""
t4 = ""
t5 = ""
for line in lines0t:
    t0 += line + " "
for line in lines1t:
    t1 += line + " "
for line in lines2t:
    t2 += line + " "
for line in lines3t:
    t3 += line + " "
for line in lines4t:
    t4 += line + " "
for line in lines5t:
    t5 += line + " "




from gensim.parsing.preprocessing import STOPWORDS 
import numpy 
stop_words = STOPWORDS 
#         +  
def filter(tokens):
    filtered_tokens = [token for token in tokens if token not in stop_words and len(token) > 1] 
    #     
    filtered_tokens = ' '.join(filtered_tokens)
    #  
    filtered_tokens = filtered_tokens.lower()
    return filtered_tokens

v0 = filter(v0.split())
v1 = filter(v1.split())
v2 = filter(v2.split())
v3 = filter(v3.split())
v4 = filter(v4.split())
v5 = filter(v5.split())

i0 = filter(i0.split())
i1 = filter(i1.split())
i2 = filter(i2.split())
i3 = filter(i3.split())
i4 = filter(i4.split())
i5 = filter(i5.split())

t0 = filter(t0.split())
t1 = filter(t1.split())
t2 = filter(t2.split())
t3 = filter(t3.split())
t4 = filter(t4.split())
t5 = filter(t5.split())



documents_v = [v0,v1,v2,v3,v4,v5]
documents_i = [i0,i1,i2,i3,i4,i5]
documents_t = [t0,t1,t2,t3,t4,t5]

#   TfidfVectorizer 
from sklearn.feature_extraction.text import TfidfVectorizer

#    ，          
# def tfidf(documentsd,index):
#     str = documentsd[index]
#     dict = {}
#     for i in str.split():
#         if i in dict:
#             dict[i] += 1
#         else:
#             dict[i] = 1

#     #  ，          
#     dict = sorted(dict.items(), key=lambda x: x[1], reverse=True)
    
#     return dict


def tfidf(documents,index):
    #      TfidfVectorizer  
    vectorizer = TfidfVectorizer()
    #   fit_transform    TF-IDF 
    tfidf_matrix = vectorizer.fit_transform(documents)
    #             TF-IDF 
    # print(vectorizer.get_feature_names())
    # print(tfidf_matrix.toarray()[0])
    #            TF-IDF 
    # word2tfidf = dict(zip(vectorizer.get_feature_names(), tfidf_matrix.toarray()[index]))

    ##            TF-IDF ,  get_feature_names_out()  
    word2tfidf = dict(zip(vectorizer.get_feature_names_out(), tfidf_matrix.toarray()[index]))
    # print(word2tfidf)
    #  ,   TF-IDF       
    sorted_word2tfidf = sorted(word2tfidf.items(), key=lambda x: x[1], reverse=True)
    # print(sorted_word2tfidf)
    return sorted_word2tfidf

sorted_word2tfidf0_v = tfidf(documents_v,0)
#   10 
print(sorted_word2tfidf0_v[:110])
sorted_word2tfidf1_v = tfidf(documents_v,1)
print(sorted_word2tfidf1_v[:110])
sorted_word2tfidf2_v = tfidf(documents_v,2)
#   10 
print(sorted_word2tfidf2_v[:110])
sorted_word2tfidf3_v = tfidf(documents_v,3)
print(sorted_word2tfidf3_v[:110])
sorted_word2tfidf4_v = tfidf(documents_v,4)
#   10 
print(sorted_word2tfidf4_v[:110])
sorted_word2tfidf5_v = tfidf(documents_v,5)
#   10 
print(sorted_word2tfidf5_v[:110])

sorted_word2tfidf0_i = tfidf(documents_i,0)
#   10 
print(sorted_word2tfidf0_i[:110])
sorted_word2tfidf1_i = tfidf(documents_i,1)
print(sorted_word2tfidf1_i[:110])
sorted_word2tfidf2_i = tfidf(documents_i,2)
#   10 
print(sorted_word2tfidf2_i[:110])
sorted_word2tfidf3_i = tfidf(documents_i,3)
print(sorted_word2tfidf3_i[:110])
sorted_word2tfidf4_i = tfidf(documents_i,4)
#   10 
print(sorted_word2tfidf4_i[:110])
sorted_word2tfidf5_i = tfidf(documents_i,5)
#   10 
print(sorted_word2tfidf5_i[:110])

sorted_word2tfidf0_t = tfidf(documents_t,0)
#   10 
print(sorted_word2tfidf0_t[:110])
sorted_word2tfidf1_t = tfidf(documents_t,1)
print(sorted_word2tfidf1_t[:110])
sorted_word2tfidf2_t = tfidf(documents_t,2)
#   10 
print(sorted_word2tfidf2_t[:110])
sorted_word2tfidf3_t = tfidf(documents_t,3)
print(sorted_word2tfidf3_t[:110])
sorted_word2tfidf4_t = tfidf(documents_t,4)
#   10 
print(sorted_word2tfidf4_t[:110])
sorted_word2tfidf5_t = tfidf(documents_t,5)
#   10 
print(sorted_word2tfidf5_t[:110])
# Out:
# [('parameter', 0.4750518210630894), ('php', 0.37214374762991614), ('crafted', 0.3328909544023964), ('vectors', 0.2432017616970129), ('vulnerability', 0.21952297365803008), ('cve', 0.18854708131218487), ('successful', 0.16110056385201627), ('file', 0.13822439944958634), ('unspecified', 0.13771970059262756), ('aka', 0.11969774557539105), ('related', 0.11492413555332258), ('compromise', 0.11001483599477932), ('url', 0.10987378500754127), ('attacks', 0.10722747798470116), ('request', 0.10638631322310318), ('note', 0.1045147216285477), ('unknown', 0.10028786870151792), ('dot', 0.09608798649102186), ('unauthorized', 0.09216054243162981), ('information', 0.08403235968363715), ('oracle', 0.08123902619329078), ('different', 0.07921669142348878), ('id', 0.0758520323770969), ('result', 0.0720113806311851), ('page', 0.0710648205217762), ('access', 0.07103636411694852), ('web', 0.06939609283183248), ('action', 0.06934159570721128), ('site', 0.06795748802562217), ('long', 0.06327661919120725), ('parameters', 0.06242083577539571), ('attacker', 0.058019339431219945), ('index', 0.05732756354932903), ('certificate', 0.05623777234874688), ('obtained', 0.055310312834749555), ('http', 0.054876215573680324), ('admin', 0.05368694774391017), ('server', 0.053007366126898645), ('html', 0.0523625064094736), ('human', 0.05140037838710718), ('person', 0.05087926856014112), ('bug', 0.05065914776723771), ('party', 0.050604559695322196), ('details', 0.05036185197496094), ('data', 0.045612159197649896), ('message', 0.044770994436051925), ('issue', 0.04456070324565243), ('demonstrated', 0.04439247029333284), ('user', 0.043614392888854714), ('2015', 0.04337186962855672), ('packet', 0.04160010326991954), ('2016', 0.03794652939266751), ('field', 0.03770521043862898), ('affected', 0.0359597935583132), ('direct', 0.035265431768490715), ('memory', 0.035034512320555426), ('sending', 0.034998453276093335), ('cvss', 0.03437161867200998), ('2014', 0.03417231843991751), ('code', 0.03417231843991751), ('asp', 0.0338944295115386), ('exploit', 0.033687831586142546), ('device', 0.033415270154479336), ('significantly', 0.03250216994652853), ('products', 0.03215192981857393), ('require', 0.03133688963960658), ('header', 0.030775338941807454), ('function', 0.03055530996504624), ('error', 0.030366047893686698), ('allow', 0.029966494631927663), ('malformed', 0.029840319917687968), ('string', 0.029587970489208575), ('triggers', 0.02920944634648949), ('document', 0.0290278433552064), ('interaction', 0.02885794795095352), ('certain', 0.028305194227771672), ('solely', 0.028205717612527274), ('inc', 0.027844946805855413), ('provenance', 0.027683261251132272), ('corruption', 0.02702241796633477), ('packets', 0.026980359728254872), ('value', 0.026812126775935276), ('additional', 0.026600766151593826), ('large', 0.026433602633216192), ('cisco', 0.02624991472950004), ('path', 0.025921184534582305), ('involving', 0.025896913762546176), ('impact', 0.025508581409968166), ('arbitrary', 0.02502465165753959), ('username', 0.024877541337028897), ('command', 0.024604069276740605), ('requests', 0.02458629207259539), ('files', 0.02451347975648701), ('delete', 0.023518378103005853), ('uri', 0.023397024242825224), ('update', 0.023324211926716847), ('cookie', 0.023253318357304462), ('attack', 0.023005856229704465), ('search', 0.022942768872584618), ('mysql', 0.021949875164603356), ('image', 0.021449701420748223), ('port', 0.021449701420748223), ('apple', 0.021187085555456533), ('content', 0.02109130089939328), ('sa', 0.021023098825151142), ('tcp', 0.02096994703921265), ('insert', 0.020966205983091037), ('password', 0.02092397344474949), ('score', 0.02086086402867108), ('containing', 0.02084859317903202)]
# [('file', 0.34065847792631226), ('vectors', 0.2937880198978091), ('cve', 0.29199298107969623), ('symlink', 0.2631596627844652), ('crafted', 0.26008117986880047), ('vulnerability', 0.23215835380926667), ('attack', 0.20523277153757338), ('directory', 0.17333602111085597), ('tmp', 0.17132518734728203), ('horse', 0.17046276029064644), ('aka', 0.16594136629665796), ('related', 0.1609551473574555), ('2015', 0.15837341636689098), ('unspecified', 0.1503843632063463), ('trojan', 0.1266066555258576), ('unknown', 0.12325933217708489), ('application', 0.11767476696517812), ('temporary', 0.11440637781154771), ('dll', 0.10819114199482377), ('different', 0.10491004648081982), ('long', 0.10131996884459404), ('files', 0.10013435482499647), ('note', 0.09753044245080017), ('command', 0.08376847817860138), ('2016', 0.08243180926463743), ('working', 0.08236633767957283), ('current', 0.07274127844758364), ('ioctl', 0.07123352574189423), ('reading', 0.07080430893667497), ('leveraging', 0.07000651390640258), ('program', 0.06482084620963202), ('argument', 0.06362415366422343), ('demonstrated', 0.06342470490665533), ('function', 0.05644399839177188), ('win32k', 0.055369290751341366), ('variable', 0.05504785708879519), ('information', 0.05484840833122709), ('call', 0.05432576491654981), ('user', 0.05305336951311421), ('kernel', 0.05105888193743322), ('certain', 0.04926384311932033), ('issue', 0.04926384311932033), ('environment', 0.048266599331479844), ('memory', 0.04806715057391174), ('windows', 0.046471560513366955), ('privilege', 0.04627211175579886), ('access', 0.04487597045282216), ('log', 0.04328038039227738), ('line', 0.04288148287714118), ('modifying', 0.04166509936396405), ('id', 0.04128589281659639), ('bug', 0.03969030275605161), ('process', 0.03869305896821111), ('obtained', 0.03865087043216201), ('party', 0.038212190576895205), ('involving', 0.03775180273861936), ('elevation', 0.03590077636225773), ('use', 0.034504635059281044), ('details', 0.034298893951550516), ('pid', 0.0331597136801191), ('malicious', 0.033147924355860905), ('value', 0.03290904499873625), ('path', 0.03245734259844713), ('setuid', 0.032253484981321405), ('contains', 0.031313454938191466), ('exe', 0.031306373002757515), ('request', 0.03071510866548717), ('library', 0.030385597326205827), ('device', 0.030116762392782877), ('large', 0.02951841612007858), ('creating', 0.028774239892240365), ('privileges', 0.02739307637741283), ('arguments', 0.026932688539136985), ('triggers', 0.0267261335141252), ('buffer', 0.026327235998989004), ('parameter', 0.026242106781723215), ('dwmapi', 0.026060024959385714), ('server', 0.02601191286258529), ('option', 0.025728889726284707), ('data', 0.02532999221114851), ('root', 0.024931094696012315), ('execution', 0.024860943266895676), ('pointer', 0.024860943266895676), ('arbitrary', 0.023534953393035626), ('folder', 0.023479779752068136), ('socket', 0.023457079986415566), ('listed', 0.02301869390786102), ('calls', 0.02293660712033133), ('null', 0.022559004075516448), ('cves', 0.022396567045486395), ('2017', 0.022124291350823774), ('code', 0.021739914574922737), ('service', 0.02154046581735464), ('string', 0.02154046581735464), ('driver', 0.021408034479826834), ('environmental', 0.020264269471183895), ('executable', 0.020026870964999294), ('permissions', 0.0199918295338769), ('dot', 0.019796677045861372), ('configuration', 0.019545978241673655), ('filesystem', 0.019545978241673655), ('execute', 0.019346529484105555), ('commands', 0.01894763196896936), ('ms11', 0.01887105255679655), ('overflow', 0.01874818321140126), ('system', 0.01874818321140126), ('leverages', 0.018422063155621723), ('incorrect', 0.018349285696265063), ('var', 0.01805362189250929), ('script', 0.017750939423560767)]
# [('exploit', 0.36124937444350946), ('attacker', 0.34008892653230655), ('successful', 0.339759379236652), ('affected', 0.28204161979486464), ('allow', 0.24789614524342826), ('device', 0.2428881423092176), ('access', 0.1734590107212969), ('crafted', 0.1659470063199809), ('cisco', 0.15302761872238807), ('arbitrary', 0.13817535368481262), ('execute', 0.1290698938044296), ('sending', 0.12584614571522984), ('user', 0.11814334194796994), ('2017', 0.10191700252882703), ('underlying', 0.10082723479959162), ('nexus', 0.09966144208762319), ('interface', 0.09957346393752006), ('privileges', 0.09904801030196586), ('local', 0.09879423970215598), ('switches', 0.09713836760439222), ('vulnerabilities', 0.09644086507951694), ('software', 0.08822665890555177), ('need', 0.08769129223767298), ('commands', 0.08741241485167718), ('code', 0.08650186886363888), ('root', 0.08581895937261015), ('credentials', 0.08564894259533387), ('vulnerability', 0.08559132287560058), ('series', 0.08396744088942168), ('system', 0.08081095643839947), ('cve', 0.07830695497129414), ('sensitive', 0.07562042609969372), ('malicious', 0.07513986988424996), ('operating', 0.07423208542398148), ('administrator', 0.07058132712444141), ('to', 0.06962260671093091), ('requests', 0.06804624580426832), ('information', 0.06760803961184407), ('ids', 0.06674478923353247), ('http', 0.06568170444427444), ('valid', 0.06510403814473874), ('cause', 0.06489352399094316), ('dos', 0.058107902934346166), ('based', 0.0578196702404323), ('authenticating', 0.05676917587269675), ('an', 0.053963872146260305), ('web', 0.05349457679725036), ('prior', 0.0532538211969674), ('file', 0.05076293883313545), ('request', 0.05030766583911629), ('condition', 0.04712075488098223), ('files', 0.04466355902210662), ('resulting', 0.04387537856877533), ('bug', 0.04325093443181944), ('cli', 0.04198372044471084), ('command', 0.04006402347368537), ('released', 0.039407827685755875), ('snmp', 0.03868714207620816), ('versions', 0.03847056799461834), ('the', 0.037332385509570465), ('specific', 0.03664947601854174), ('reload', 0.03468220384563069), ('updates', 0.03468220384563069), ('context', 0.03415448631102271), ('management', 0.0341454745514364), ('input', 0.033234928563398096), ('script', 0.03186910958134064), ('this', 0.03186910958134064), ('service', 0.030958563593302336), ('denial', 0.030476310862143342), ('parameter', 0.03021358404436624), ('platform', 0.030177165344948194), ('application', 0.03004801760526403), ('address', 0.02890983512021615), ('browser', 0.028454562126197), ('gain', 0.026981936073130153), ('administrative', 0.026772227529960536), ('level', 0.026405833653110816), ('targeted', 0.025916859649190802), ('data', 0.024812378174043782), ('affects', 0.023121469230420463), ('persuading', 0.022721630377372758), ('running', 0.022308376706938447), ('submitting', 0.02130152847878696), ('specially', 0.0200791706474704), ('vedge', 0.019999631758905994), ('api', 0.019576738742823535), ('payload', 0.019526401105554713), ('vulnerable', 0.01916648107258538), ('nx', 0.018923058624232252), ('fabric', 0.018816350156261815), ('configuration', 0.018666192754785232), ('link', 0.01812815042661975), ('os', 0.017755646766746926), ('elevated', 0.017751273732322468), ('view', 0.017077243155511356), ('unauthorized', 0.01704122278302957), ('click', 0.016428412347930327), ('i7', 0.01597947172712946), ('releases', 0.01597614635909022), ('sql', 0.01576360906662587), ('directory', 0.015500882248848769), ('server', 0.015500882248848769), ('read', 0.015479281796651168), ('9000', 0.015266095409797323), ('obtain', 0.015266095409797323), ('database', 0.015238155431071671), ('injecting', 0.015238155431071671), ('php', 0.015238155431071671), ('shell', 0.01479637230562244)]
# [('cve', 0.3927568245078728), ('crafted', 0.35115122869136084), ('2012', 0.2602301069012669), ('related', 0.24464090340109027), ('function', 0.23631978423778788), ('file', 0.226334441241825), ('vectors', 0.21468487441320167), ('demonstrated', 0.16309393560072685), ('vulnerability', 0.16142971176806636), ('note', 0.14811592110678254), ('string', 0.13147368278017776), ('triggers', 0.12980945894751728), ('long', 0.12315256361687536), ('buffer', 0.11483144445357298), ('different', 0.1131672206209125), ('large', 0.10817454912293106), ('argument', 0.10151765379228915), ('issue', 0.10151765379228915), ('overflow', 0.09985342995962868), ('unspecified', 0.09319653462898676), ('value', 0.08653963929834485), ('application', 0.0832111916330239), ('heap', 0.08154696780036343), ('xml', 0.08067213284969227), ('image', 0.07988274396770294), ('based', 0.07821852013504246), ('aka', 0.07489007246972151), ('memory', 0.07156162480440055), ('data', 0.06490472947375864), ('unknown', 0.06324050564109816), ('regular', 0.06229319433781633), ('attack', 0.05991205797577721), ('document', 0.05954371710334429), ('outside', 0.05782891264472598), ('parameter', 0.05762295203549448), ('input', 0.05658361031045625), ('involving', 0.05570218696764466), ('certain', 0.054919386477795776), ('integer', 0.05115634580110375), ('expression', 0.04893215685322968), ('filters', 0.04893215685322968), ('containing', 0.04609836162839558), ('leveraging', 0.04493404348183291), ('read', 0.04493404348183291), ('access', 0.043269819649172425), ('reading', 0.043269819649172425), ('2008', 0.042256831492695955), ('files', 0.042256831492695955), ('values', 0.042256831492695955), ('number', 0.04160559581651195), ('trigger', 0.04160559581651195), ('ext', 0.039966122628628205), ('functions', 0.03994137198385147), ('in', 0.03994137198385147), ('hash', 0.03893324646113521), ('arguments', 0.03841530135699632), ('length', 0.03841530135699632), ('invalid', 0.038277148151190994), ('brute', 0.037811212113859294), ('1770', 0.03749101821504957), ('3108', 0.03749101821504957), ('userspace', 0.03689180550334911), ('table', 0.036494536289146506), ('handled', 0.03457377122129669), ('maintains', 0.03381748837807002), ('2007', 0.03336283421811114), ('bmp', 0.03336283421811114), ('size', 0.033284476653209556), ('web', 0.033284476653209556), ('1766', 0.030743171252790927), ('1769', 0.030743171252790927), ('1771', 0.030743171252790927), ('1772', 0.030743171252790927), ('1773', 0.030743171252790927), ('3106', 0.030743171252790927), ('3107', 0.030743171252790927), ('3110', 0.030743171252790927), ('interruption', 0.030743171252790927), ('format', 0.030732241085597054), ('metacharacters', 0.030732241085597054), ('php', 0.030732241085597054), ('error', 0.029956028987888603), ('force', 0.029956028987888603), ('request', 0.029956028987888603), ('shell', 0.029956028987888603), ('2013', 0.02881147601774724), ('pointer', 0.02881147601774724), ('reference', 0.02881147601774724), ('characters', 0.028291805155228125), ('filename', 0.028291805155228125), ('use', 0.028291805155228125), ('10', 0.02689071094989742), ('of', 0.02689071094989742), ('out', 0.02689071094989742), ('character', 0.026627581322567647), ('fix', 0.026627581322567647), ('information', 0.026627581322567647), ('local', 0.026627581322567647), ('variable', 0.026627581322567647), ('1767', 0.025955497640756803), ('environments', 0.025955497640756803), ('utf', 0.025955497640756803), ('bounds', 0.024969945882047605), ('party', 0.024969945882047605), ('server', 0.024969945882047605), ('stack', 0.024969945882047605), ('api', 0.02496335748990717), ('arbitrary', 0.02496335748990717), ('multiple', 0.02496335748990717), ('applet', 0.02459453700223274)]
# [('crafted', 0.394435442958265), ('device', 0.3648527847363951), ('vectors', 0.25145259488589394), ('unattended', 0.2368079186972466), ('workstation', 0.2368079186972466), ('usb', 0.236661265774959), ('unspecified', 0.21693949362704573), ('leveraging', 0.18242639236819755), ('aka', 0.1676350632572626), ('reading', 0.1627046202202843), ('hid', 0.1614815328417406), ('screen', 0.15284373414632768), ('descriptor', 0.11201980396378614), ('vulnerability', 0.10353930377654455), ('data', 0.08874797466560962), ('connecting', 0.08535711274467137), ('cve', 0.0838175316286313), ('serial', 0.07966663856169326), ('bug', 0.078887088591653), ('related', 0.07395664555467468), ('drivers', 0.06920637121788883), ('password', 0.06902620251769637), ('value', 0.06902620251769637), ('lock', 0.0658940023316389), ('internal', 0.06409575948071806), ('windows', 0.06409575948071806), ('bluetooth', 0.05930460209847501), ('boot', 0.05930460209847501), ('button', 0.05930460209847501), ('input', 0.05916531644373975), ('use', 0.05916531644373975), ('siri', 0.0555355974599029), ('key', 0.05423487340676143), ('line', 0.05423487340676143), ('endpoints', 0.052715201865311125), ('pressing', 0.052715201865311125), ('call', 0.05121426764680282), ('access', 0.049304430369783124), ('application', 0.049304430369783124), ('attack', 0.049304430369783124), ('different', 0.049304430369783124), ('state', 0.049304430369783124), ('user', 0.049304430369783124), ('emergency', 0.04613758081192589), ('inserting', 0.04612580163214724), ('locked', 0.04612580163214724), ('cable', 0.04553998436485511), ('involving', 0.04552379346382473), ('lockscreen', 0.04442847796792232), ('note', 0.04437398733280481), ('card', 0.03983331928084663), ('visiting', 0.03983331928084663), ('keyboard', 0.039536401398983345), ('facetime', 0.03643198749188409), ('tap', 0.03643198749188409), ('demonstrated', 0.03451310125884818), ('feature', 0.03451310125884818), ('filesystem', 0.03451310125884818), ('image', 0.03451310125884818), ('invalid', 0.03451310125884818), ('time', 0.03451310125884818), ('2013', 0.034142845097868545), ('authentication', 0.034142845097868545), ('entering', 0.034142845097868545), ('modified', 0.034142845097868545), ('hdmi', 0.03332135847594174), ('spoofer', 0.03332135847594174), ('devices', 0.03294700116581945), ('endpoint', 0.03294700116581945), ('interrupt', 0.03294700116581945), ('attaching', 0.030758387207950596), ('certain', 0.029582658221869874), ('command', 0.029582658221869874), ('dialog', 0.029582658221869874), ('id', 0.029582658221869874), ('in', 0.029582658221869874), ('issue', 0.029582658221869874), ('large', 0.029582658221869874), ('report', 0.029582658221869874), ('session', 0.029582658221869874), ('provides', 0.028452370914890453), ('captured', 0.02732399061891307), ('gps', 0.02732399061891307), ('icloud', 0.02732399061891307), ('inspector', 0.02732399061891307), ('presenting', 0.02732399061891307), ('sleep', 0.02732399061891307), ('tapping', 0.02732399061891307), ('thunderbolt', 0.02732399061891307), ('contact', 0.026357600932655562), ('fi', 0.026357600932655562), ('making', 0.026357600932655562), ('series', 0.026357600932655562), ('wi', 0.026357600932655562), ('arbitrary', 0.024652215184891562), ('browser', 0.024652215184891562), ('crash', 0.024652215184891562), ('error', 0.024652215184891562), ('mode', 0.024652215184891562), ('option', 0.024652215184891562), ('privilege', 0.024652215184891562), ('process', 0.024652215184891562), ('program', 0.024652215184891562), ('request', 0.024652215184891562), ('trigger', 0.024652215184891562), ('triggers', 0.024652215184891562), ('web', 0.024652215184891562), ('authorized', 0.023068790405962946), ('bulk', 0.023068790405962946), ('kerberos', 0.023068790405962946)]
# [('file', 0.6171140899812205), ('crafted', 0.4814197872128833), ('long', 0.21003118167620888), ('cve', 0.17699256882826592), ('note', 0.1545735101100189), ('vulnerability', 0.11563514496780039), ('related', 0.11209529359123507), ('triggers', 0.10383564037924933), ('aka', 0.10029578900268402), ('issue', 0.09557598716726359), ('malformed', 0.09321608624955338), ('vectors', 0.09203613579069828), ('demonstrated', 0.08731633395527785), ('memory', 0.08259653211985743), ('image', 0.08023663120214722), ('user', 0.07905668074329211), ('document', 0.07353939370950573), ('information', 0.07315692844901658), ('string', 0.07315692844901658), ('archive', 0.07217755308525563), ('containing', 0.07081571246100551), ('filename', 0.06961707707245125), ('corruption', 0.06489727523703083), ('different', 0.06489727523703083), ('2006', 0.06400650933975499), ('overflow', 0.06371732477817572), ('web', 0.06371732477817572), ('site', 0.0630788411539324), ('2007', 0.05677095703853916), ('url', 0.05583546559425435), ('obtained', 0.05519398600969085), ('details', 0.05447362497000424), ('function', 0.05191782018962467), ('involving', 0.05174994372150403), ('large', 0.049557919271914455), ('party', 0.04766442184875371), ('handled', 0.046302581224503606), ('certain', 0.04483811743649403), ('m3u', 0.04359439916011873), ('properly', 0.04247821651878382), ('excel', 0.042326195386077604), ('project', 0.042326195386077604), ('zip', 0.04221705935175329), ('unspecified', 0.041298266059928715), ('attribute', 0.041001246750056064), ('element', 0.04085521872750318), ('header', 0.04085521872750318), ('format', 0.039493378103253075), ('page', 0.039493378103253075), ('record', 0.039493378103253075), ('buffer', 0.0389383651422185), ('data', 0.0389383651422185), ('field', 0.03539851376565318), ('name', 0.03539851376565318), ('value', 0.03539851376565318), ('drag', 0.03487551932809499), ('possibly', 0.034218563306798074), ('dot', 0.03404601560625265), ('html', 0.03185866238908786), ('object', 0.03132233435775244), ('xls', 0.03128457919840518), ('message', 0.03067871193023276), ('microsoft', 0.02949876147137765), ('tricking', 0.029444309833793116), ('argument', 0.028318811012522545), ('uri', 0.02723681248500212), ('code', 0.02713886055366744), ('contains', 0.02713886055366744), ('invalid', 0.02713886055366744), ('files', 0.025874971860752015), ('mp3', 0.025763771104568976), ('rar', 0.025763771104568976), ('src', 0.025763771104568976), ('specifiers', 0.025231536461572963), ('line', 0.024778959635957228), ('2008', 0.02451313123650191), ('playlist', 0.023976919538065303), ('drop', 0.023923501739956905), ('attachment', 0.023654565432724654), ('based', 0.023599009177102122), ('characters', 0.023599009177102122), ('tag', 0.023599009177102122), ('extension', 0.023151290612251803), ('pdf', 0.023151290612251803), ('text', 0.023151290612251803), ('error', 0.022419058718247016), ('gif', 0.022083232375344836), ('tar', 0.022077594403876345), ('content', 0.021789449988001697), ('directory', 0.021789449988001697), ('values', 0.021789449988001697), ('operation', 0.02123910825939191), ('sequences', 0.02123910825939191), ('unknown', 0.02123910825939191), ('javascript', 0.02042760936375159), ('results', 0.02042760936375159), ('movie', 0.02024296301073277), ('solely', 0.02024296301073277), ('number', 0.020059157800536805), ('action', 0.019065768739501485), ('execution', 0.019065768739501485), ('length', 0.019065768739501485), ('mail', 0.019065768739501485), ('font', 0.018923652346179723), ('integer', 0.018923652346179723), ('office', 0.018923652346179723), ('section', 0.018923652346179723), ('doc', 0.018402693646120696), ('ppt', 0.018402693646120696), ('and', 0.01770392811525138)]
# [('arbitrary', 0.5342364919333802), ('execute', 0.3411500085246767), ('cause', 0.22921268946394827), ('code', 0.22763553793093944), ('service', 0.22360503956880579), ('cvss', 0.21887574132948068), ('denial', 0.21631239871959407), ('script', 0.15965483773332168), ('web', 0.15801171170879802), ('html', 0.15635656979340118), ('inject', 0.14329163073404905), ('oracle', 0.12338664250263615), ('commands', 0.11138464202779372), ('sql', 0.10204405385820083), ('crash', 0.10091073825729927), ('data', 0.09666456105304475), ('vulnerability', 0.09144782905924635), ('obtain', 0.08981675781570732), ('information', 0.08919668114460984), ('accessible', 0.08415710234770063), ('av', 0.08374354767636033), ('ac', 0.08371864623488652), ('pr', 0.08366884335193894), ('access', 0.0821736388480492), ('base', 0.07873303729506341), ('sensitive', 0.07831837954513875), ('score', 0.07782902645295721), ('files', 0.07512363669622346), ('read', 0.0680466746891326), ('confidentiality', 0.06475184512240156), ('integrity', 0.06143801931483993), ('vector', 0.0606403380436358), ('impacts', 0.05582162909639039), ('ui', 0.05431251593520035), ('memory', 0.05365011197756493), ('application', 0.05292219588540701), ('attacks', 0.0528682761748768), ('attacker', 0.05188548858318338), ('an', 0.05133940642844989), ('bypass', 0.050940646523421576), ('availability', 0.05033544399700488), ('php', 0.04868056784910968), ('servers', 0.04853290943241935), ('possibly', 0.04627659156255789), ('the', 0.044618560463753745), ('exploit', 0.04417372285187947), ('unauthorized', 0.04412211263025729), ('user', 0.04387716444396328), ('affect', 0.043250872042353755), ('authentication', 0.043064177630660144), ('corruption', 0.04283921001625662), ('dos', 0.04196292188009254), ('affected', 0.03674768336835956), ('complete', 0.03612117581030593), ('malicious', 0.03394726719295536), ('spoof', 0.03364589937085479), ('virtualbox', 0.03313048623137907), ('server', 0.03144867116674849), ('successful', 0.030904556695258538), ('impact', 0.030572475870632478), ('result', 0.030336921980447663), ('conduct', 0.028752685640237686), ('installations', 0.028163530306858017), ('unspecified', 0.02775517099542869), ('critical', 0.027437681176606454), ('java', 0.02708624756321507), ('can', 0.026818852467273287), ('was', 0.02666944381843054), ('zdi', 0.02666944381843054), ('device', 0.026097139896624547), ('file', 0.025814061416340916), ('frequently', 0.025720918274956983), ('repeatable', 0.025720918274956983), ('mysql', 0.024555457292559164), ('interaction', 0.024014726860417862), ('hijack', 0.023850211093859108), ('required', 0.02344121137089338), ('compromise', 0.023230976291333794), ('requests', 0.022999717703818257), ('exists', 0.022843716173300714), ('site', 0.022543350212003814), ('subset', 0.02192751879806439), ('process', 0.02141960500812831), ('this', 0.021384456701662415), ('management', 0.021296813559385643), ('enterprise', 0.021212719527561808), ('visit', 0.021086578479826062), ('cross', 0.02067640609506768), ('se', 0.020649615616258263), ('potentially', 0.020427480212809525), ('specific', 0.020287459404039317), ('vm', 0.02026749266164298), ('flaw', 0.020249477112610412), ('page', 0.020177414916480122), ('gain', 0.019721134126426506), ('users', 0.019518935211938194), ('insert', 0.01864785155693491), ('lack', 0.018185334381903832), ('context', 0.018124915801921628), ('target', 0.017853409091278395), ('consumption', 0.017645225271013188), ('partial', 0.01742103591449668), ('delete', 0.017335186935464448), ('leverage', 0.0172070016110947), ('hang', 0.0171734278038738), ('scripting', 0.017129212272889025), ('results', 0.017008017936370173), ('current', 0.01695263163964982), ('include', 0.01656652426929505), ('prior', 0.016556289560933246)]
# [('privileges', 0.4386240834811735), ('gain', 0.4025745463480323), ('arbitrary', 0.34343277902284336), ('service', 0.25632375513172995), ('cause', 0.2501658270805172), ('denial', 0.24644541221624283), ('execute', 0.21732354414071597), ('code', 0.19140893025852906), ('files', 0.178323333149702), ('obtain', 0.1690864410728829), ('information', 0.13111255142373773), ('sensitive', 0.12341514135972181), ('root', 0.10373102968149699), ('overwrite', 0.1009811376959321), ('kernel', 0.0978853979807357), ('access', 0.09557617496153092), ('memory', 0.09519130445833014), ('crash', 0.0890333764071174), ('possibly', 0.07594777929829034), ('affect', 0.07580988636410152), ('read', 0.06966156107934401), ('bypass', 0.06876352990520883), ('availability', 0.06772521772593605), ('system', 0.05774581187890545), ('escalate', 0.056823677373713896), ('context', 0.05359995871836865), ('vulnerability', 0.05234238843530822), ('unspecified', 0.052085808099841015), ('attacker', 0.05137896595379536), ('impact', 0.050289745751570636), ('bsod', 0.04913124764569273), ('confidentiality', 0.04634471568742925), ('an', 0.04501875848269587), ('ioctl', 0.04242123727297559), ('integrity', 0.04219886252689245), ('data', 0.040796273339284345), ('user', 0.04028311266834995), ('installations', 0.037444444073352755), ('file', 0.03720414864274359), ('modify', 0.0360495371331412), ('the', 0.032457412436600434), ('validating', 0.03201333936547262), ('privileged', 0.03143109109473165), ('ibm', 0.031012922510301598), ('exploit', 0.030661350088330055), ('commands', 0.030276479585129263), ('write', 0.030019899249662065), ('target', 0.030004843296300782), ('permission', 0.02961233891306217), ('order', 0.02949047455407848), ('low', 0.029412255542027966), ('values', 0.029147562059263617), ('versions', 0.028633193317041318), ('prior', 0.02829028082222645), ('corruption', 0.028223836901391686), ('input', 0.02811882457481902), ('restrictions', 0.02783896639819089), ('intended', 0.0268126450563221), ('ability', 0.02531931751613547), ('issue', 0.024888292540318123), ('id', 0.02413478804169638), ('this', 0.02366096214222576), ('panic', 0.02354252330447684), ('process', 0.02334881052751494), ('affected', 0.021321530539903554), ('can', 0.0210921235603063), ('was', 0.0210921235603063), ('zdi', 0.020855133407943306), ('create', 0.020581199618379124), ('parallels', 0.02023051373646171), ('force', 0.020141556334174974), ('password', 0.020141556334174974), ('outside', 0.019888924699262234), ('passwords', 0.019396670143940038), ('flaw', 0.019374555957039935), ('permissions', 0.018517274720002766), ('exists', 0.017831449730373036), ('dll', 0.017407253279975738), ('levels', 0.017317080988150737), ('note', 0.01717567737936675), ('users', 0.016549431637634216), ('pointer', 0.016421141469900615), ('lack', 0.016406836424804717), ('results', 0.016406836424804717), ('suse', 0.016352320513046456), ('consumption', 0.016292851302167018), ('dereference', 0.01616456113443342), ('specific', 0.01613921408923255), ('protection', 0.01590798079896622), ('proper', 0.015806586311702106), ('null', 0.015523110295765426), ('leverage', 0.015250816983403236), ('host', 0.015088149771854109), ('server', 0.014881659457097433), ('blocked', 0.014806169456531085), ('conduct', 0.014625079121630236), ('linux', 0.014606086085496883), ('15', 0.014406002714462678), ('mode', 0.014214353693269035), ('hijacking', 0.01400583597239427), ('delete', 0.013727047947495047), ('qemu', 0.013034458379964566), ('elevated', 0.013005419117223251), ('potentially', 0.012881758034525063), ('application', 0.012829016773359856), ('consequently', 0.012829016773359856), ('locations', 0.012733691850220177), ('affects', 0.012687762308150045), ('attacks', 0.012572436437892659), ('of', 0.011930985599224666)]
# [('vulnerability', 0.3615690232559845), ('an', 0.3561864352745974), ('attacker', 0.31380403014002284), ('affected', 0.253683798971198), ('exploit', 0.24758285660240292), ('arbitrary', 0.17976313020636517), ('user', 0.1789460250690635), ('the', 0.17547332823553147), ('device', 0.17016214484307066), ('input', 0.16489778789103912), ('insufficient', 0.16025203662175536), ('validation', 0.14853233582886133), ('execute', 0.1446276093023938), ('vulnerabilities', 0.12848978284068602), ('interface', 0.12694945590949205), ('management', 0.11947219430051342), ('information', 0.11378189036925614), ('potentially', 0.11316749396484672), ('web', 0.10765360183949368), ('enable', 0.10161497895593527), ('supplied', 0.09828344973638094), ('code', 0.09498847221131795), ('privileges', 0.09335426193671464), ('improper', 0.0887281143453439), ('this', 0.08845510476274285), ('based', 0.08676174537304915), ('commands', 0.08661314455397595), ('escalation', 0.08315264723315735), ('access', 0.08314044772044389), ('system', 0.07850994893811242), ('privilege', 0.075916527201418), ('root', 0.07535064479789205), ('ibm', 0.07009035398963455), ('service', 0.06863683153333942), ('files', 0.06373420070952947), ('cause', 0.06087433272897366), ('denial', 0.05985295130734659), ('these', 0.05962274458802557), ('sensitive', 0.05413321534623496), ('attack', 0.05375455963330219), ('operating', 0.05288635801036061), ('id', 0.05186843473388807), ('command', 0.050779782363796815), ('underlying', 0.04762465371020633), ('site', 0.04738888809777956), ('unexpectedly', 0.04364717498445424), ('scripting', 0.042909341461671045), ('cross', 0.04267357584924428), ('force', 0.0422851908553609), ('software', 0.042202044624390755), ('perform', 0.04208091457103548), ('conduct', 0.041059533149408405), ('xss', 0.03960862288769635), ('versions', 0.03904037031195132), ('disclosure', 0.038549694694299), ('dos', 0.03727532462176019), ('obtain', 0.034726968335320546), ('releases', 0.03472658447668257), ('cli', 0.03467221699033439), ('file', 0.034522692050995125), ('condition', 0.03412619782513227), ('inject', 0.03227565292341556), ('injection', 0.030649529615479315), ('server', 0.029824337511510583), ('gain', 0.029007232374208925), ('os', 0.02880295608988351), ('attacks', 0.028598679805558094), ('restart', 0.02839440352123268), ('administrator', 0.028119987007908992), ('cisco', 0.027717549077719117), ('application', 0.027373022099605605), ('sql', 0.027348811041504623), ('data', 0.026964469530954775), ('read', 0.025738811825002286), ('allow', 0.025487401450776197), ('known', 0.025389891181898407), ('valid', 0.025389891181898407), ('elevated', 0.025168808932641496), ('pan', 0.025168808932641496), ('exists', 0.025116881599297352), ('users', 0.024921706687700624), ('credentials', 0.02471743040337521), ('more', 0.024528344292542165), ('certain', 0.02430887783472438), ('orchestrator', 0.024150985149579977), ('shell', 0.023812326855103164), ('http', 0.0235765612426764), ('view', 0.0235765612426764), ('scripts', 0.023205814521089944), ('elevate', 0.02293866130569858), ('10', 0.022301476269429174), ('aruba', 0.021886830291806856), ('parameters', 0.021664291233159768), ('stored', 0.02104045728551774), ('resulting', 0.021021737860281477), ('for', 0.020708513678755664), ('level', 0.019804311443848175), ('advisory', 0.019434143606216852), ('authorization', 0.01938368036467513), ('properly', 0.01911555108808215), ('request', 0.018837661199473013), ('section', 0.018478366051812745), ('execution', 0.018389717769287592), ('executed', 0.0182916420342709), ('specific', 0.018153952156860827), ('html', 0.017918186544434063), ('modify', 0.017567760451985687), ('successful', 0.017522588497408637), ('run', 0.017472613286467722), ('malicious', 0.017446655319580534)]
# [('cause', 0.4050361585154774), ('service', 0.402618032195982), ('denial', 0.40140896903623435), ('arbitrary', 0.3518373794865789), ('execute', 0.3155654846941481), ('code', 0.2925932846589419), ('crash', 0.2333491898313049), ('obtain', 0.14387851600997556), ('application', 0.12936975809300325), ('information', 0.12695163177350785), ('possibly', 0.11969725281502169), ('memory', 0.118488189655274), ('sensitive', 0.1172791264955263), ('impact', 0.07496191590435702), ('consumption', 0.07012566326536625), ('unspecified', 0.06770753694587085), ('read', 0.05803503166788931), ('bypass', 0.05319877902889853), ('cpu', 0.0446541141688606), ('availability', 0.04201286297843209), ('affect', 0.03767690882997613), ('corruption', 0.036271894792430814), ('access', 0.035062831632683124), ('passwords', 0.033490585626645454), ('files', 0.03143564215344004), ('bounds', 0.030699703491091666), ('cleartext', 0.030699703491091666), ('out', 0.02780845267419696), ('of', 0.026599389514449265), ('restrictions', 0.026599389514449265), ('related', 0.02511793921998409), ('stack', 0.024181263194953877), ('commands', 0.022972200035206183), ('intended', 0.022972200035206183), ('leveraging', 0.02262231083454036), ('unknown', 0.02262231083454036), ('attacks', 0.02176313687545849), ('demonstrated', 0.020554073715710795), ('issue', 0.020554073715710795), ('pointer', 0.020554073715710795), ('process', 0.020554073715710795), ('protection', 0.020554073715710795), ('buffer', 0.019536174948876512), ('contents', 0.0193450105559631), ('dereference', 0.0193450105559631), ('null', 0.0193450105559631), ('password', 0.0193450105559631), ('infinite', 0.01814073388109962), ('note', 0.01814073388109962), ('privileges', 0.018135947396215407), ('cryptographic', 0.01697106593298232), ('file', 0.016926884236467713), ('gain', 0.016926884236467713), ('segmentation', 0.01615879345324311), ('conduct', 0.01571782107672002), ('cve', 0.014508757916972327), ('trigger', 0.014508757916972327), ('determine', 0.013954410677768937), ('locations', 0.013954410677768937), ('loop', 0.013954410677768937), ('overflow', 0.013954410677768937), ('heap', 0.013299694757224633), ('fault', 0.01292703476259449), ('mechanisms', 0.01292703476259449), ('values', 0.01292703476259449), ('based', 0.012558969609992044), ('discover', 0.012090631597476939), ('safe_mode', 0.011314043955321549), ('defeat', 0.01131115541727018), ('authentication', 0.01116352854221515), ('use', 0.009768087474438256), ('predict', 0.008933999152299626), ('reading', 0.008463442118233857), ('server', 0.008463442118233857), ('session', 0.008463442118233857), ('write', 0.008463442118233857), ('knowledge', 0.008372646406661364), ('mechanism', 0.008372646406661364), ('cert8', 0.008171198138554813), ('xml', 0.008079396726621555), ('entity', 0.007542695970214365), ('recursion', 0.007542695970214365), ('xxe', 0.007542695970214365), ('applications', 0.007254378958486163), ('key', 0.007254378958486163), ('modify', 0.007254378958486163), ('spoof', 0.007254378958486163), ('vulnerability', 0.007254378958486163), ('web', 0.007254378958486163), ('exhaustion', 0.0069772053388844684), ('guess', 0.0069772053388844684), ('keys', 0.0069772053388844684), ('obtained', 0.0069772053388844684), ('port', 0.0069772053388844684), ('air', 0.00670049936422472), ('referer', 0.00670049936422472), ('assertion', 0.006463517381297245), ('database', 0.006463517381297245), ('decrypt', 0.006463517381297245), ('logs', 0.006463517381297245), ('strings', 0.006463517381297245), ('hang', 0.006045315798738469), ('security', 0.006045315798738469), ('user', 0.006045315798738469), ('2010', 0.005657021977660774), ('anti', 0.005657021977660774), ('child', 0.005657021977660774), ('compiled', 0.005657021977660774), ('csrf', 0.005657021977660774), ('db', 0.005657021977660774)]
# [('bypass', 0.38601676012776465), ('obtain', 0.352450085334046), ('cause', 0.2584633959116337), ('service', 0.2584633959116337), ('information', 0.2483933934735181), ('sensitive', 0.24503672599414625), ('denial', 0.24168005851477437), ('arbitrary', 0.23161005607665877), ('access', 0.22489672111791503), ('screen', 0.1929019944312417), ('intended', 0.1476933690923621), ('execute', 0.13762336665424652), ('protection', 0.13762336665424652), ('passcode', 0.13087778989194407), ('lock', 0.1256106010249946), ('code', 0.12419669673675905), ('mechanism', 0.11622300159813267), ('crash', 0.100700024381156), ('password', 0.09734335690178413), ('requirement', 0.09423200872219972), ('read', 0.08727335446366853), ('data', 0.08056001950492479), ('device', 0.0704900170668092), ('dereference', 0.06377668210806546), ('null', 0.06377668210806546), ('pointer', 0.06377668210806546), ('locking', 0.058319207618747496), ('memory', 0.05706334714932173), ('restrictions', 0.05370667966994986), ('contact', 0.044860928937498074), ('locked', 0.044860928937498074), ('workstation', 0.044860928937498074), ('gain', 0.043636677231834266), ('modify', 0.043636677231834266), ('authentication', 0.04261510058598198), ('drive', 0.040374836043748266), ('unattended', 0.040374836043748266), ('possibly', 0.040280009752462397), ('reset', 0.03874100053271089), ('photo', 0.03720458791604974), ('discover', 0.03692334227309053), ('bounds', 0.03486690047943981), ('user', 0.033566674793718665), ('factory', 0.03140265025624865), ('guesses', 0.031003823263374784), ('system', 0.030992800426168712), ('view', 0.030992800426168712), ('corruption', 0.030210007314346796), ('of', 0.030210007314346796), ('out', 0.030210007314346796), ('privileges', 0.030210007314346796), ('state', 0.030210007314346796), ('based', 0.02711870037289762), ('cleartext', 0.02711870037289762), ('infinite', 0.02711870037289762), ('loop', 0.02711870037289762), ('root', 0.026916557362498844), ('heap', 0.02685333983497493), ('key', 0.02685333983497493), ('process', 0.02685333983497493), ('reading', 0.02685333983497493), ('session', 0.02685333983497493), ('unspecified', 0.02685333983497493), ('write', 0.02685333983497493), ('oops', 0.026175557978388813), ('notification', 0.024803058610699827), ('commands', 0.023496672355603064), ('impact', 0.023496672355603064), ('feature', 0.023244600319626534), ('keys', 0.023244600319626534), ('sed', 0.022685328585244892), ('boot', 0.022430464468749037), ('defeat', 0.022430464468749037), ('leveraging', 0.022430464468749037), ('telephone', 0.022430464468749037), ('dial', 0.02094044638271105), ('account', 0.020140004876231198), ('administrative', 0.020140004876231198), ('application', 0.020140004876231198), ('contents', 0.020140004876231198), ('delete', 0.020140004876231198), ('demonstrated', 0.020140004876231198), ('login', 0.019370500266355443), ('mode', 0.019370500266355443), ('encrypting', 0.01860229395802487), ('find', 0.01860229395802487), ('health', 0.01860229395802487), ('human', 0.01860229395802487), ('iphone', 0.01860229395802487), ('my', 0.01860229395802487), ('changes', 0.01794437157499923), ('firmware', 0.01794437157499923), ('media', 0.01794437157499923), ('pin', 0.01794437157499923), ('attacks', 0.016783337396859332), ('conduct', 0.016783337396859332), ('credentials', 0.016783337396859332), ('local', 0.016783337396859332), ('private', 0.016783337396859332), ('apple', 0.015705334787033287), ('photos', 0.015705334787033287), ('unlock', 0.015705334787033287), ('console', 0.015496400213084356), ('disk', 0.015496400213084356), ('extract', 0.015496400213084356), ('home', 0.015496400213084356), ('id', 0.015496400213084356), ('message', 0.015496400213084356), ('numbers', 0.015496400213084356), ('related', 0.015496400213084356)]
# [('arbitrary', 0.5359545233706713), ('execute', 0.46392595303328343), ('code', 0.4252009152174835), ('cause', 0.18742918302847178), ('denial', 0.18200767773425977), ('service', 0.18200767773425977), ('cross', 0.16983920914147882), ('site', 0.16805142799262116), ('scripting', 0.16715753741819234), ('perform', 0.14018463689319582), ('stored', 0.13708663386793182), ('attacks', 0.13553763235529984), ('crash', 0.12546912252319184), ('admins', 0.08938634694155846), ('high', 0.07866750561244329), ('application', 0.07667557487528391), ('possibly', 0.07512657336265191), ('users', 0.07125406958107192), ('privilege', 0.0697234648054492), ('files', 0.05344055218580393), ('web', 0.03407803327790396), ('script', 0.03396784182829577), ('html', 0.03307395125386693), ('jenkins', 0.03290687257024877), ('credentials', 0.031754531008955963), ('inject', 0.03098003025263996), ('commands', 0.030205529496323963), ('bypass', 0.029431028740007963), ('impact', 0.02323502268947997), ('read', 0.02246052193316397), ('unspecified', 0.020137019664215976), ('attacker', 0.019665592637434393), ('memory', 0.019362518907899976), ('obtain', 0.019362518907899976), ('attack', 0.018771702063005557), ('specified', 0.018771702063005557), ('url', 0.018631777645052354), ('information', 0.018588018151583976), ('access', 0.01781351739526798), ('overwrite', 0.016983920914147885), ('conduct', 0.01626451588263598), ('sensitive', 0.01626451588263598), ('same', 0.015738069490118977), ('corruption', 0.01549001512631998), ('xss', 0.014302249190861377), ('admin', 0.013456283854760035), ('origin', 0.013287159680501936), ('capturing', 0.012876602310097343), ('local', 0.012392012101055984), ('posts', 0.012079236073183576), ('file', 0.011617511344739985), ('restrictions', 0.011617511344739985), ('zone', 0.011445868720086528), ('enumerate', 0.011386086338643107), ('shortcode', 0.010468599737402025), ('intended', 0.010068509832107988), ('id', 0.009832796318717196), ('javascript', 0.009832796318717196), ('malicious', 0.009832796318717196), ('policy', 0.009832796318717196), ('examination', 0.008584401540064896), ('irc', 0.008584401540064896), ('connect', 0.00851950831947599), ('modify', 0.00851950831947599), ('payload', 0.008455465251228504), ('download', 0.008280790064467714), ('trick', 0.008280790064467714), ('triggered', 0.008280790064467714), ('create', 0.008045015169859525), ('ids', 0.008045015169859525), ('method', 0.008045015169859525), ('obtained', 0.008045015169859525), ('privileges', 0.00774500756315999), ('programs', 0.00774500756315999), ('chrome', 0.007247541643910145), ('bar', 0.007151124595430688), ('contributor', 0.006979066491601351), ('spoof', 0.006970506806843991), ('page', 0.006210592548350786), ('certain', 0.006196006050527992), ('consumption', 0.006196006050527992), ('trigger', 0.006196006050527992), ('user', 0.006196006050527992), ('embed', 0.006039618036591788), ('ntfs', 0.006039618036591788), ('approval', 0.005722934360043264), ('set', 0.005421505294211993), ('executing', 0.005363343446573016), ('loop', 0.005363343446573016), ('prevent', 0.005363343446573016), ('plugin', 0.005175493790292321), ('unknown', 0.005175493790292321), ('clipboard', 0.00483169442927343), ('invoked', 0.00483169442927343), ('post', 0.00483169442927343), ('word', 0.00483169442927343), ('client', 0.004647004537895994), ('delete', 0.004647004537895994), ('mail', 0.004647004537895994), ('password', 0.004647004537895994), ('security', 0.004647004537895994), ('infinite', 0.004469452872144179), ('java', 0.004469452872144179), ('redirect', 0.004469452872144179), ('view', 0.004469452872144179), ('approved', 0.004292200770032448), ('disallows', 0.004292200770032448), ('unfiltered_html', 0.004292200770032448), ('arguments', 0.004140395032233857), ('command', 0.004140395032233857)]
# ...
# [('vulnerability', 0.8437778067574849), ('vulnerabilities', 0.26825870552264863), ('multiple', 0.23308059785430524), ('improper', 0.19142811325144587), ('an', 0.0931766932347575), ('permissions', 0.09138674923114566), ('cross', 0.08941956850754954), ('stored', 0.08732511593198364), ('xss', 0.08566244378034157), ('scripting', 0.0834081689440168), ('site', 0.08190531905313361), ('control', 0.07439106959871768), ('the', 0.06966375410729235), ('access', 0.06762824508974336), ('injection', 0.06687682014430175), ('insufficient', 0.06600154111138298), ('path', 0.06003881733795348), ('wordpress', 0.05178582456431588), ('input', 0.04358264683561238), ('validation', 0.042636261587822036), ('plugin', 0.040576947053846006), ('incorrect', 0.03960092466682979), ('uncontrolled', 0.03960092466682979), ('buffer', 0.03711059798238938), ('command', 0.03654536707527603), ('overflow', 0.035157408614895205), ('discovered', 0.034565547490313264), ('issue', 0.03381412254487168), ('csrf', 0.033508474718086746), ('search', 0.03306485592524974), ('identified', 0.030462249743715225), ('file', 0.030056997817663706), ('neutralization', 0.028864980316024247), ('execution', 0.028714216987716878), ('authorisation', 0.0274160247693437), ('bounds', 0.0274160247693437), ('traversal', 0.02554844814501415), ('remote', 0.024045598254130968), ('exists', 0.023493450262677445), ('sql', 0.023438272409930138), ('code', 0.023294173308689374), ('out', 0.021753194687664304), ('elements', 0.02164873523701818), ('authenticated', 0.021323574820600655), ('privilege', 0.02030816649581015), ('directory', 0.02018295679743984), ('cwe', 0.018277349846229134), ('flaw', 0.018277349846229134), ('special', 0.018277349846229134), ('vulnerable', 0.018277349846229134), ('check', 0.017402555750131443), ('element', 0.017261941521438624), ('information', 0.016927641184949542), ('default', 0.016276578062451485), ('kernel', 0.016276578062451485), ('server', 0.016276578062451485), ('escalation', 0.01624653319664812), ('insecure', 0.01624653319664812), ('write', 0.01624653319664812), ('checks', 0.015231124871857613), ('read', 0.015231124871857613), ('version', 0.015231124871857613), ('resource', 0.014792172387611725), ('inherited', 0.014666908925165915), ('of', 0.014215716547067103), ('request', 0.013922044600105155), ('protection', 0.01352564901794867), ('forgery', 0.013200308222276596), ('initialization', 0.013200308222276596), ('based', 0.013021262449961187), ('service', 0.013021262449961187), ('stack', 0.013021262449961187), ('web', 0.013021262449961187), ('management', 0.012774224072507076), ('denial', 0.01218489989748609), ('flow', 0.01218489989748609), ('upload', 0.01218489989748609), ('os', 0.01218178902509201), ('pointer', 0.011169491572695582), ('versions', 0.011169491572695582), ('2019', 0.01082436761850909), ('addons', 0.01082436761850909), ('persistent', 0.01082436761850909), ('unquoted', 0.01082436761850909), ('conditions', 0.010441533450078866), ('external', 0.010441533450078866), ('authorization', 0.010154083247905074), ('disclosure', 0.010154083247905074), ('bypass', 0.009571405662572294), ('restrictions', 0.009571405662572294), ('affected', 0.009138674923114567), ('arbitrary', 0.009138674923114567), ('attacker', 0.009138674923114567), ('elementor', 0.009138674923114567), ('prior', 0.009138674923114567), ('reported', 0.009138674923114567), ('royal', 0.009138674923114567), ('in', 0.009017099345299113), ('password', 0.009017099345299113), ('use', 0.009017099345299113), ('alc', 0.00880014535509955), ('scalance', 0.00880014535509955), ('06b04', 0.008418952592173738), ('827dru', 0.008418952592173738), ('tew', 0.008418952592173738), ('trendnet', 0.008418952592173738), ('exposure', 0.00826567439985752), ('memory', 0.00826567439985752), ('xml', 0.00826567439985752), ('contain', 0.00812326659832406)]
# [('the', 0.5611085075689027), ('overflow', 0.43162192889915596), ('buffer', 0.33990226900808534), ('function', 0.3021353502294092), ('integer', 0.2589731573394936), ('vulnerability', 0.21041569033833854), ('based', 0.18074168272652155), ('multiple', 0.18074168272652155), ('overflows', 0.1321842157253665), ('unspecified', 0.12678894161412707), ('stack', 0.10790548222478899), ('heap', 0.08362674872421147), ('stores', 0.059156113191743465), ('error', 0.05665037816801422), ('passwords', 0.05407975543974536), ('off', 0.05048732810476981), ('functions', 0.04670219462506064), ('free', 0.04585982994553532), ('vulnerabilities', 0.04358871498338992), ('one', 0.04326380435179628), ('by', 0.03736175570004851), ('format', 0.0342482760583778), ('implementation', 0.0342482760583778), ('string', 0.0342482760583778), ('after', 0.031134796416707085), ('memory', 0.031134796416707085), ('use', 0.031134796416707085), ('extension', 0.02884253623453086), ('leak', 0.02884253623453086), ('system', 0.025243664052384904), ('library', 0.02490783713336567), ('password', 0.02490783713336567), ('xml', 0.02490783713336567), ('java', 0.024278733500577524), ('underflow', 0.02179435749169496), ('parser', 0.02163190217589814), ('earlier', 0.021581096444957797), ('libxml2', 0.019933356643790215), ('regular', 0.019933356643790215), ('safe_mode', 0.019933356643790215), ('server', 0.018883459389338074), ('array', 0.018680877850024254), ('injection', 0.018680877850024254), ('interface', 0.018680877850024254), ('tre', 0.018231410584022986), ('module', 0.018026585146581786), ('php', 0.018026585146581786), ('script', 0.018026585146581786), ('signedness', 0.018026585146581786), ('cs', 0.016829109368256604), ('expression', 0.016829109368256604), ('macro', 0.016829109368256604), ('method', 0.016829109368256604), ('sun', 0.016829109368256604), ('xslt', 0.016829109368256604), ('double', 0.01618582233371835), ('index', 0.01618582233371835), ('properly', 0.01618582233371835), ('stylesheets', 0.014950017482842661), ('aka', 0.013488185278098624), ('web', 0.013488185278098624), ('dl', 0.012621832026192452), ('process', 0.012621832026192452), ('session', 0.012621832026192452), ('cleartext', 0.012453918566682836), ('consumption', 0.012453918566682836), ('addw', 0.01215427372268199), ('ccn', 0.01215427372268199), ('dsig', 0.01215427372268199), ('estate', 0.01215427372268199), ('fiddle', 0.01215427372268199), ('iconv_substr', 0.01215427372268199), ('mole', 0.01215427372268199), ('shell_quote', 0.01215427372268199), ('splash', 0.01215427372268199), ('weblogin', 0.01215427372268199), ('ziparchive', 0.01215427372268199), ('admin', 0.01081595108794907), ('api', 0.01081595108794907), ('portal', 0.01081595108794907), ('configuration', 0.010790548222478899), ('functionality', 0.010790548222478899), ('manager', 0.010790548222478899), ('user', 0.010790548222478899), ('aaa', 0.009966678321895107), ('digital', 0.009966678321895107), ('imageio', 0.009966678321895107), ('regex', 0.009966678321895107), ('spring', 0.009966678321895107), ('syntax', 0.009966678321895107), ('zend', 0.009966678321895107), ('account', 0.009340438925012127), ('code', 0.009340438925012127), ('management', 0.009340438925012127), ('time', 0.009340438925012127), ('traversal', 0.009340438925012127), ('cms', 0.008414554684128302), ('decompression', 0.008414554684128302), ('enabled', 0.008414554684128302), ('eval', 0.008414554684128302), ('foundation', 0.008414554684128302), ('group', 0.008414554684128302), ('message', 0.008414554684128302), ('perl', 0.008414554684128302), ('photo', 0.008414554684128302), ('rb', 0.008414554684128302), ('run', 0.008414554684128302), ('default', 0.008092911166859175), ('directory', 0.008092911166859175), ('errors', 0.008092911166859175)]
# [('the', 0.6705164761997328), ('hid', 0.24262092149406744), ('passcode', 0.20431235494237257), ('lock', 0.19400680151957375), ('an', 0.19147473323908437), ('discovered', 0.19147473323908437), ('issue', 0.19147473323908437), ('drivers', 0.17249452904774093), ('function', 0.1589884428102459), ('feature', 0.11060065586799717), ('usb', 0.10780908065483807), ('drives', 0.09343389818652148), ('siri', 0.09343389818652148), ('buffer', 0.08295049190099787), ('component', 0.08295049190099787), ('vulnerability', 0.08295049190099787), ('driver', 0.07978113884961847), ('implementation', 0.07978113884961847), ('ifix', 0.07661713310338972), ('12', 0.07180302496465664), ('screen', 0.07180302496465664), ('overflow', 0.06912540991749823), ('tivoli', 0.06466893383985793), ('manager', 0.0622128689257484), ('multiple', 0.0622128689257484), ('race', 0.0622128689257484), ('server', 0.0622128689257484), ('storage', 0.05584679719473293), ('condition', 0.05530032793399858), ('anydana', 0.05107808873559314), ('dnp3', 0.05107808873559314), ('springboard', 0.05107808873559314), ('xscreensaver', 0.05107808873559314), ('based', 0.04838778694224876), ('java', 0.04838778694224876), ('seagate', 0.04671694909326074), ('st500lt015', 0.04671694909326074), ('systemui', 0.04671694909326074), ('mode', 0.04312363226193523), ('kernel', 0.04147524595049894), ('control', 0.03989056942480924), ('data', 0.03989056942480924), ('settings', 0.03830856655169486), ('disk', 0.03695367647991881), ('hard', 0.03695367647991881), ('improper', 0.03695367647991881), ('subsystem', 0.03695367647991881), ('overflows', 0.034562704958749114), ('unspecified', 0.034562704958749114), ('power', 0.03234272419645142), ('unity', 0.03234272419645142), ('wizard', 0.03234272419645142), ('access', 0.03191245553984739), ('ibm', 0.03191245553984739), ('microsoft', 0.03191245553984739), ('password', 0.03191245553984739), ('protection', 0.03191245553984739), ('3x48', 0.03114463272884049), ('databases', 0.03114463272884049), ('dock', 0.03114463272884049), ('fastfat', 0.03114463272884049), ('pm851', 0.03114463272884049), ('st500lt025', 0.03114463272884049), ('android', 0.02771525735993911), ('encryption', 0.02771525735993911), ('mobile', 0.02771525735993911), ('setup', 0.02771525735993911), ('heap', 0.02765016396699929), ('integer', 0.02765016396699929), ('login', 0.02765016396699929), ('security', 0.02765016396699929), ('stack', 0.02765016396699929), ('850', 0.02553904436779657), ('co', 0.02553904436779657), ('developments', 0.02553904436779657), ('diabecare', 0.02553904436779657), ('dnp', 0.02553904436779657), ('fi', 0.02553904436779657), ('flashcopy', 0.02553904436779657), ('ltd', 0.02553904436779657), ('rs', 0.02553904436779657), ('solid', 0.02553904436779657), ('sooil', 0.02553904436779657), ('track', 0.02553904436779657), ('wi', 0.02553904436779657), ('array', 0.023934341654885546), ('device', 0.023934341654885546), ('mail', 0.023934341654885546), ('management', 0.023934341654885546), ('1x44', 0.021561816130967616), ('1x46', 0.021561816130967616), ('1x47', 0.021561816130967616), ('host', 0.021561816130967616), ('master', 0.021561816130967616), ('my', 0.021561816130967616), ('operating', 0.021561816130967616), ('place', 0.021561816130967616), ('serial', 0.021561816130967616), ('state', 0.021561816130967616), ('telephony', 0.021561816130967616), ('update', 0.021561816130967616), ('window', 0.021561816130967616), ('application', 0.02073762297524947), ('index', 0.02073762297524947), ('console', 0.018476838239959405), ('exchange', 0.018476838239959405), ('js', 0.018476838239959405), ('packages', 0.018476838239959405), ('passwords', 0.018476838239959405), ('private', 0.018476838239959405)]
# [('buffer', 0.419095033822138), ('overflow', 0.39133164041436225), ('shortcode', 0.3216566291081427), ('the', 0.2617691378447423), ('wordpress', 0.25567752899967733), ('vulnerability', 0.2485484743172301), ('based', 0.2445822752589764), ('outputting', 0.2391822045480852), ('plugin', 0.1968364275947894), ('escape', 0.19612645227196163), ('stack', 0.19566582020718112), ('attributes', 0.18552502241942317), ('validate', 0.17394847089772086), ('unspecified', 0.11766390539485892), ('multiple', 0.11105357363110281), ('overflows', 0.07006951669581486), ('cross', 0.06561214253159646), ('site', 0.05950868741237819), ('scripting', 0.05493109607296448), ('heap', 0.05156058775729773), ('xss', 0.050353504733550776), ('integer', 0.05023852140454651), ('vulnerabilities', 0.042724185834527924), ('permission', 0.03710500448388463), ('function', 0.037017857877034266), ('check', 0.03357119453303848), ('missing', 0.03204313937589595), ('after', 0.02899141181628681), ('use', 0.02899141181628681), ('format', 0.02746554803648224), ('string', 0.02746554803648224), ('traversal', 0.02746554803648224), ('free', 0.02644132705502448), ('injection', 0.024413820476873103), ('escapes', 0.023826416970973534), ('wp', 0.022969764680500007), ('directory', 0.022475127996770806), ('webkit', 0.02198025310254525), ('post', 0.017669049754230778), ('word', 0.017095752413090748), ('slider', 0.0146535020683635), ('options', 0.014433408895143073), ('block', 0.014135239803384622), ('crlf', 0.014135239803384622), ('page', 0.014135239803384622), ('social', 0.014135239803384622), ('windows', 0.01322066352751224), ('exe', 0.012371493338694063), ('pdf', 0.012371493338694063), ('explorer', 0.012368334827961545), ('drag', 0.01221125172363625), ('easy', 0.01221125172363625), ('player', 0.01221125172363625), ('carousel', 0.011913208485486767), ('implementation', 0.010681046458631981), ('content', 0.010309577782245052), ('forgery', 0.010309577782245052), ('mozilla', 0.010309577782245052), ('chrome', 0.009769001378908999), ('posts', 0.009769001378908999), ('error', 0.009254464469258566), ('dll', 0.009155182678827414), ('simple', 0.009155182678827414), ('archive_read_support_format_tar', 0.008934906364115074), ('flipbook', 0.008934906364115074), ('html5', 0.008934906364115074), ('netrw', 0.008934906364115074), ('testimonials', 0.008934906364115074), ('argument', 0.008834524877115389), ('blacklist', 0.008834524877115389), ('google', 0.008834524877115389), ('request', 0.008834524877115389), ('video', 0.008834524877115389), ('checks', 0.008247662225796043), ('developer', 0.008247662225796043), ('download', 0.008247662225796043), ('drop', 0.008247662225796043), ('woocommerce', 0.008247662225796043), ('zone', 0.008247662225796043), ('10', 0.007932398116507344), ('java', 0.007932398116507344), ('manager', 0.007932398116507344), ('web', 0.007932398116507344), ('incomplete', 0.007629318899022844), ('microsoft', 0.007629318899022844), ('category', 0.00732675103418175), ('firefox', 0.00732675103418175), ('grid', 0.00732675103418175), ('portfolio', 0.00732675103418175), ('seamonkey', 0.00732675103418175), ('toolbar', 0.00732675103418175), ('visual', 0.00732675103418175), ('widget', 0.00732675103418175), ('widgets', 0.00732675103418175), ('13', 0.007067619901692311), ('19', 0.007067619901692311), ('handle', 0.007067619901692311), ('signedness', 0.007067619901692311), ('start', 0.007067619901692311), ('viewer', 0.007067619901692311), ('companion', 0.006185746669347032), ('custom', 0.006185746669347032), ('event', 0.006185746669347032), ('list', 0.006185746669347032), ('12', 0.006103455119218276), ('mail', 0.006103455119218276), ('1410', 0.0059566042427433834), ('balloon', 0.0059566042427433834), ('gtkutils', 0.0059566042427433834), ('icat', 0.0059566042427433834)]

# %%
#          0   
def count_not_zero(sorted_word2tfidf):
    count = 0
    for i in range(len(sorted_word2tfidf)):
        if sorted_word2tfidf[i][1] != 0:
            count += 1
    return count

# print(count_not_zero(sorted_word2tfidf0_v))
# print(count_not_zero(sorted_word2tfidf1_v))
# print(count_not_zero(sorted_word2tfidf2_v))
# print(count_not_zero(sorted_word2tfidf3_v))
# print(count_not_zero(sorted_word2tfidf4_v))
# print(count_not_zero(sorted_word2tfidf5_v))
# import matplotlib.pyplot as plt
import numpy as np
#    ，           
def maintain_set(sorted_word2tfidf):
    set_words = set()
    # bb= 0
    # list_temp = []
    # last_ = count_not_zero(sorted_word2tfidf)
    for i in range(int(count_not_zero(sorted_word2tfidf) )):
        
        # list_temp.append(sorted_word2tfidf[i][1])
            
        set_words.add(sorted_word2tfidf[i][0])
        # bb += 1
        # if bb >1000:
        #     break
    # plt.plot(list_temp)
    # plt.show()
    return set_words
print("111vvv"*10)
set_v0 = maintain_set(sorted_word2tfidf0_v)
print("222vvv"*10)
set_v1 = maintain_set(sorted_word2tfidf1_v)
# set_v2 = maintain_set(sorted_word2tfidf2_v)
# set_v3 = maintain_set(sorted_word2tfidf3_v)
# set_v4 = maintain_set(sorted_word2tfidf4_v)
# set_v5 = maintain_set(sorted_word2tfidf5_v)
print("111iii"*10)
set_i0 = maintain_set(sorted_word2tfidf0_i)
print("222iii"*10)
set_i1 = maintain_set(sorted_word2tfidf1_i)
# set_i2 = maintain_set(sorted_word2tfidf2_i)
# set_i3 = maintain_set(sorted_word2tfidf3_i)
# set_i4 = maintain_set(sorted_word2tfidf4_i)
# set_i5 = maintain_set(sorted_word2tfidf5_i)
print("111ttt"*10)
set_t0 = maintain_set(sorted_word2tfidf0_t)
print("222ttt"*10)
set_t1 = maintain_set(sorted_word2tfidf1_t)
# set_t2 = maintain_set(sorted_word2tfidf2_t)
# set_t3 = maintain_set(sorted_word2tfidf3_t)
# set_t4 = maintain_set(sorted_word2tfidf4_t)
# set_t5 = maintain_set(sorted_word2tfidf5_t)
# Out:
# 111vvv111vvv111vvv111vvv111vvv111vvv111vvv111vvv111vvv111vvv
# 222vvv222vvv222vvv222vvv222vvv222vvv222vvv222vvv222vvv222vvv
# 111iii111iii111iii111iii111iii111iii111iii111iii111iii111iii
# 222iii222iii222iii222iii222iii222iii222iii222iii222iii222iii
# 111ttt111ttt111ttt111ttt111ttt111ttt111ttt111ttt111ttt111ttt
# 222ttt222ttt222ttt222ttt222ttt222ttt222ttt222ttt222ttt222ttt

# %%
#    other 

# #      ，            ，               index，index/count_not_zero(sorted_word2tfidf)
# def get_weight(sorted_word2tfidf,set,words):
#     score = 0.0
#     words = filter(words.split()).split()
#     for word in words:
#         if word in set:
#             #  key word index
#             index = 0
#             for i in range(len(sorted_word2tfidf)):
#                 if sorted_word2tfidf[i][0] == word:
#                     index = i
#                     break
#             # score += 100 * (count_not_zero(sorted_word2tfidf) / 3 - index) * sorted_word2tfidf[index][1]/(count_not_zero(sorted_word2tfidf) / 3)
#             # score += 100 * sorted_word2tfidf[index][1]
#             score += 1/(index+0.1) 
#         else:
#             score += 0
#     return score
    
import csv
import math
import time

from tqdm import tqdm
#       




# path6_v_i_t = "/home/user/lh/PMA_lihang/mypaper/data/1_3_aspects/AttType6_headTo_v_i_t.csv"
# f6_v = open(path6_v_i_t, 'r')
# lines6 = csv.reader(f6_v)

# ii = 0
# for line in lines6:
#     print(line)
#     v6 = line[1]
#     i6 = line[2]
#     t6 = line[3]
#     #print(v6,i6,t6)
#     score_0 = 7 * (get_weight(sorted_word2tfidf0_v,set_v0,v6) * 5 + get_weight(sorted_word2tfidf0_i,set_i0,i6) * 4 + get_weight(sorted_word2tfidf0_t,set_t0,t6) * 3) 
#     score_1 = 1 * (get_weight(sorted_word2tfidf1_v,set_v1,v6) * 5 + get_weight(sorted_word2tfidf1_i,set_i1,i6) * 4 + get_weight(sorted_word2tfidf1_t,set_t1,t6) * 3)
#     score_2 = 0.3 * (get_weight(sorted_word2tfidf2_v,set_v2,v6) * 5 + get_weight(sorted_word2tfidf2_i,set_i2,i6) * 4 + get_weight(sorted_word2tfidf2_t,set_t2,t6) * 3)
#     score_3 = 0.08 * (get_weight(sorted_word2tfidf3_v,set_v3,v6) * 5 + get_weight(sorted_word2tfidf3_i,set_i3,i6) * 4 + get_weight(sorted_word2tfidf3_t,set_t3,t6) * 3)
#     score_4 = 0.04 * (get_weight(sorted_word2tfidf4_v,set_v4,v6) * 5 + get_weight(sorted_word2tfidf4_i,set_i4,i6) * 4 + get_weight(sorted_word2tfidf4_t,set_t4,t6) * 3)
#     score_5 = 0.1 * (get_weight(sorted_word2tfidf5_v,set_v5,v6) * 5 + get_weight(sorted_word2tfidf5_i,set_i5,i6) * 4 + get_weight(sorted_word2tfidf5_t,set_t5,t6) * 3)
#     #        index
#     list_temp = [score_0,score_1, score_2, score_3, score_4, score_5]
#     print(list_temp.index(max(list_temp)))
#     # print(score_0,score_1,score_2,score_3,score_4,score_5)
#     ii += 1
#     if ii == 10:
#         break
#     # v6 = filter(v6.split())



import numpy as np

# list_0 = [30185, 54381, 22348, 73408, 6060, 56685, 54584, 18600, 20211, 40647, 41183, 74778, 65506, 54372, 70666, 52842, 39757, 69397, 20409, 36700, 78402, 9857, 59140, 14152, 68414, 62456, 17887, 26046, 44000, 40829, 66620, 53738, 43327, 69629, 2292, 40831, 32127, 59079, 76654, 60879, 7886, 35037, 56437, 71663, 42746, 54114, 73271, 8571, 21803, 24824, 52491, 54135, 31808, 57702, 11583, 22230, 63783, 1603, 70816, 54207, 22911, 13872, 57626, 43208, 50594, 13740, 40045, 48923, 63613, 61673, 75718, 70784, 13385, 64043, 9631, 62143, 41431, 69712, 5606, 15382, 19979, 74887, 38844, 28205, 33152, 28835, 28218, 41018, 24471, 39325, 57204, 10289, 31418, 27744, 71569, 33049, 14072, 53713, 43411, 31834]
# list_1 = [3415, 8755, 2475, 3922, 4897, 7432, 5078, 921, 5301, 95, 3264, 4064, 1554, 818, 7766, 5882, 9075, 52, 9882, 3512, 5274, 1338, 2380, 1162, 5596, 1287, 56, 9211, 3779, 2044, 4885, 2073, 378, 2271, 735, 2054, 8095, 830, 8933, 3765, 4151, 809, 9121, 1653, 7768, 5092, 9475, 8204, 1460, 2863, 6050, 1666, 8071, 5502, 6593, 8888, 3225, 5705, 298, 6582, 2462, 4033, 98, 1081, 8434, 10630, 2283, 4578, 8191, 8906, 5224, 7548, 7489, 1520, 8019, 3579, 5860, 2009, 7114, 5643, 4060, 9480, 7197, 1532, 151, 9680, 7160, 3448, 6813, 1295, 2890, 10443, 587, 1848, 8722, 6764, 10029, 564, 7797, 6250]

#p1 0.1 3.5,  0.1
pf = [0.001,0.0001,0.00001,0.000001,0.0000001,0.00000001,0.000000001,0.0000000001,0.00000000001]
p0 = [1]
p1 = [1]

    
path0 = "/home/user/lh/PMA_lihang/mypaper/data/1_3_aspects/AttType0_headTo_v_i_t.csv"
path1 = "/home/user/lh/PMA_lihang/mypaper/data/1_3_aspects/AttType1_headTo_v_i_t.csv"
#          100    
import random
import numpy as np
import csv
import multiprocessing

def random_num(path,length):
    f = open(path, 'r')
    
    lines = list(csv.reader(f))
    # print(length)
    #  100    
    list_ = []
    while len(list_) < 5000:
        random_num = random.randint(0, length)
        
        #       
        if lines[random_num][1] == '' and lines[random_num][2] == '' and lines[random_num][3] == '':
            continue
        else:
            list_.append(random_num)
        # print(lines[random_num])
        # print(random_num)
    return list_

# list_0 = random_num(path0, 78466)
# list_1 = random_num(path1,10691)
# print("    index")   

path6_v_i_t_0 = "/home/user/lh/PMA_lihang/mypaper/data/1_3_aspects/AttType0_headTo_v_i_t.csv"
f6_v_0 = open(path6_v_i_t_0, 'r')
lines6_0 = list(csv.reader(f6_v_0))

path6_v_i_t_1 = "/home/user/lh/PMA_lihang/mypaper/data/1_3_aspects/AttType1_headTo_v_i_t.csv"
f6_v_1 = open(path6_v_i_t_1, 'r')
lines6_1 = list(csv.reader(f6_v_1))

def runsome(start):
    time1 = time.time()
    print(f"     {start}\n")
    #    
    def get_weight(sorted_word2tfidf,set,words):
        score = 0.0
        words = filter(words.split()).split()
        for word in words:
            if word in set:
                #  key word index
                index = 0
                for i in range(len(sorted_word2tfidf)):
                    if sorted_word2tfidf[i][0] == word:
                        index = i
                        break
                # score += 100 * (count_not_zero(sorted_word2tfidf) / 3 - index) * sorted_word2tfidf[index][1]/(count_not_zero(sorted_word2tfidf) / 3)
                # score += 100 * sorted_word2tfidf[index][1]
                # score += 1 / math.exp(index / (count_not_zero(sorted_word2tfidf)) + start) 
                score += math.pi/2 - math.atan(start*index) 
                # score += sorted_word2tfidf[index][1]
            else:
                score += 0
        return score
    
    
    para0 = 0
    para1 = 0
    sum = 0
    sum0 = 0
    sum1 = 0
    sum = 0

    list_0 = random_num(path0, 78466)
    list_1 = random_num(path1,10691)

    for pi0 in p0 :
        for pi1 in p1:
            
            ii = 0
            jj = 0
            wrong = 0
            for i in list_0:
                line = lines6_0[i]
                # print(line)
                v6 = line[1]
                i6 = line[2]
                t6 = line[3]
                # #print(v6,i6,t6)
                score_0 = pi0 * (get_weight(sorted_word2tfidf0_v,set_v0,v6) * 5 + get_weight(sorted_word2tfidf0_i,set_i0,i6) * 4 + get_weight(sorted_word2tfidf0_t,set_t0,t6) * 3) 
                score_1 = pi1 * (get_weight(sorted_word2tfidf1_v,set_v1,v6) * 5 + get_weight(sorted_word2tfidf1_i,set_i1,i6) * 4 + get_weight(sorted_word2tfidf1_t,set_t1,t6) * 3)
                
                list_temp = [score_0,score_1]#, score_2, score_3, score_4, score_5]
                #class_ = list_temp.index(max(list_temp))
            
                ii += 1
                

                if class_ == 0:
                    jj += 1
                # else:
                #     wrong += 1
                #     if wrong > 300 - sum0 + 100:
                #         break

                # if ii == 100:
                #     break
            
            temp = jj
            wrong = 0
            
            ii = 0
            kk = 0
            for i in list_1:
                line = lines6_1[i]
                
                # print(line)
                v6 = line[1]
                i6 = line[2]
                t6 = line[3]
                # #print(v6,i6,t6)
                score_0 = pi0 * (get_weight(sorted_word2tfidf0_v,set_v0,v6) * 5 + get_weight(sorted_word2tfidf0_i,set_i0,i6) * 4 + get_weight(sorted_word2tfidf0_t,set_t0,t6) * 3) 
                score_1 = pi1 * (get_weight(sorted_word2tfidf1_v,set_v1,v6) * 5 + get_weight(sorted_word2tfidf1_i,set_i1,i6) * 4 + get_weight(sorted_word2tfidf1_t,set_t1,t6) * 3)
                
                list_temp = [score_0,score_1]#, score_2, score_3, score_4, score_5]
                class_ = list_temp.index(max(list_temp))
                
                
                ii += 1
                

                if class_ == 1:
                    kk += 1
                # else:
                #     wrong += 1
                #     if wrong > 300 - sum1 + 100:
                #         break
                # if ii == 100:
                #     break
            temp += kk
            if temp > sum:
                sum = temp
                para0 = pi0
                para1 = pi1
                sum0 = jj
                sum1 = kk
            # break
        # break
    print(f"  :{start}   ：{time.time()- time1} p0: {para0} p1: {para1} sum:{sum} sum0: {sum0} sum1: {sum1} \n")


def sum8(start):
    print(f"     {start}\n")

    print("     \n")

pool = multiprocessing.Pool(processes=9)
for i in range(9):
    start = pf[i]
    
    # end = (i + 2) * 0.01
    #  run  

    pool.apply_async(runsome, (start,))

pool.close()
pool.join()



# print(sum)
# print(para0,para1)
# print(sum0,sum1)
# print(pf_)
# Out:
#      0.001
#      1e-11
#
#      1e-06
#      1e-07
#      1e-08
#      1e-09
#      1e-10
#
#
#
#
#
#
#      1e-05
#
#      0.0001

# %%
#    other 

    
import csv
import math
#       



path6_v_i_t = "/home/user/lh/PMA_lihang/mypaper/data/1_3_aspects/AttType6_headTo_v_i_t.csv"
f6_v = open(path6_v_i_t, 'r')
lines6 = csv.reader(f6_v)

import numpy as np

ii = 0
jj = 0
for line in lines6:
    # print(line)
    v6 = line[1]
    i6 = line[2]
    t6 = line[3]
    # #print(v6,i6,t6)
    score_0 = math.log(1+7) * (get_weight(sorted_word2tfidf0_v,set_v0,v6) * 5 + get_weight(sorted_word2tfidf0_i,set_i0,i6) * 4 + get_weight(sorted_word2tfidf0_t,set_t0,t6) * 3) 
    score_1 = math.log(1+1) * (get_weight(sorted_word2tfidf1_v,set_v1,v6) * 5 + get_weight(sorted_word2tfidf1_i,set_i1,i6) * 4 + get_weight(sorted_word2tfidf1_t,set_t1,t6) * 3)
    # score_2 = math.log(1+0.3) * (get_weight(sorted_word2tfidf2_v,set_v2,v6) * 5 + get_weight(sorted_word2tfidf2_i,set_i2,i6) * 4 + get_weight(sorted_word2tfidf2_t,set_t2,t6) * 3)
    # score_3 = math.log(1+0.08) * (get_weight(sorted_word2tfidf3_v,set_v3,v6) * 5 + get_weight(sorted_word2tfidf3_i,set_i3,i6) * 4 + get_weight(sorted_word2tfidf3_t,set_t3,t6) * 3)
    # score_4 = math.log(1+0.04) * (get_weight(sorted_word2tfidf4_v,set_v4,v6) * 5 + get_weight(sorted_word2tfidf4_i,set_i4,i6) * 4 + get_weight(sorted_word2tfidf4_t,set_t4,t6) * 3)
    # score_5 = math.log(1+0.1) * (get_weight(sorted_word2tfidf5_v,set_v5,v6) * 5 + get_weight(sorted_word2tfidf5_i,set_i5,i6) * 4 + get_weight(sorted_word2tfidf5_t,set_t5,t6) * 3)

    # score_0 = para0 * (get_weight(sorted_word2tfidf0_v,set_v0,v6) * 5 + get_weight(sorted_word2tfidf0_i,set_i0,i6) * 4 + get_weight(sorted_word2tfidf0_t,set_t0,t6) * 3) 
    # score_1 = para1 * (get_weight(sorted_word2tfidf1_v,set_v1,v6) * 5 + get_weight(sorted_word2tfidf1_i,set_i1,i6) * 4 + get_weight(sorted_word2tfidf1_t,set_t1,t6) * 3)
    # score_2 = para2 * (get_weight(sorted_word2tfidf2_v,set_v2,v6) * 5 + get_weight(sorted_word2tfidf2_i,set_i2,i6) * 4 + get_weight(sorted_word2tfidf2_t,set_t2,t6) * 3)
    # score_3 = para3 * (get_weight(sorted_word2tfidf3_v,set_v3,v6) * 5 + get_weight(sorted_word2tfidf3_i,set_i3,i6) * 4 + get_weight(sorted_word2tfidf3_t,set_t3,t6) * 3)
    # score_4 = para4 * (get_weight(sorted_word2tfidf4_v,set_v4,v6) * 5 + get_weight(sorted_word2tfidf4_i,set_i4,i6) * 4 + get_weight(sorted_word2tfidf4_t,set_t4,t6) * 3)
    # score_5 = para5 * (get_weight(sorted_word2tfidf5_v,set_v5,v6) * 5 + get_weight(sorted_word2tfidf5_i,set_i5,i6) * 4 + get_weight(sorted_word2tfidf5_t,set_t5,t6) * 3)

    list_temp = [score_0,score_1]#, score_2, score_3, score_4, score_5]
    class_ = list_temp.index(max(list_temp))
    # print(class_)

    # score_0 = np.arctan(10*7) * (get_weight(sorted_word2tfidf0_v,set_v0,v6) * 5 + get_weight(sorted_word2tfidf0_i,set_i0,i6) * 4 + get_weight(sorted_word2tfidf0_t,set_t0,t6) * 3) 
    # score_1 = np.arctan(10*1) * (get_weight(sorted_word2tfidf1_v,set_v1,v6) * 5 + get_weight(sorted_word2tfidf1_i,set_i1,i6) * 4 + get_weight(sorted_word2tfidf1_t,set_t1,t6) * 3)
    # score_2 = np.arctan(10*0.3) * (get_weight(sorted_word2tfidf2_v,set_v2,v6) * 5 + get_weight(sorted_word2tfidf2_i,set_i2,i6) * 4 + get_weight(sorted_word2tfidf2_t,set_t2,t6) * 3)
    # score_3 = np.arctan(10*0.08) * (get_weight(sorted_word2tfidf3_v,set_v3,v6) * 5 + get_weight(sorted_word2tfidf3_i,set_i3,i6) * 4 + get_weight(sorted_word2tfidf3_t,set_t3,t6) * 3)
    # score_4 = np.arctan(10*0.04) * (get_weight(sorted_word2tfidf4_v,set_v4,v6) * 5 + get_weight(sorted_word2tfidf4_i,set_i4,i6) * 4 + get_weight(sorted_word2tfidf4_t,set_t4,t6) * 3)
    # score_5 = np.arctan(10*0.1) * (get_weight(sorted_word2tfidf5_v,set_v5,v6) * 5 + get_weight(sorted_word2tfidf5_i,set_i5,i6) * 4 + get_weight(sorted_word2tfidf5_t,set_t5,t6) * 3)

    # score_0 = (get_weight(sorted_word2tfidf0_v,set_v0,v6) * 5 + get_weight(sorted_word2tfidf0_i,set_i0,i6) * 4 + get_weight(sorted_word2tfidf0_t,set_t0,t6) * 3) 
    # score_1 = (get_weight(sorted_word2tfidf1_v,set_v1,v6) * 5 + get_weight(sorted_word2tfidf1_i,set_i1,i6) * 4 + get_weight(sorted_word2tfidf1_t,set_t1,t6) * 3)
    # score_2 = (get_weight(sorted_word2tfidf2_v,set_v2,v6) * 5 + get_weight(sorted_word2tfidf2_i,set_i2,i6) * 4 + get_weight(sorted_word2tfidf2_t,set_t2,t6) * 3)
    # score_3 = (get_weight(sorted_word2tfidf3_v,set_v3,v6) * 5 + get_weight(sorted_word2tfidf3_i,set_i3,i6) * 4 + get_weight(sorted_word2tfidf3_t,set_t3,t6) * 3)
    # score_4 = (get_weight(sorted_word2tfidf4_v,set_v4,v6) * 5 + get_weight(sorted_word2tfidf4_i,set_i4,i6) * 4 + get_weight(sorted_word2tfidf4_t,set_t4,t6) * 3)
    # score_5 = (get_weight(sorted_word2tfidf5_v,set_v5,v6) * 5 + get_weight(sorted_word2tfidf5_i,set_i5,i6) * 4 + get_weight(sorted_word2tfidf5_t,set_t5,t6) * 3)
    #        index
    
    # print(list_temp.index(max(list_temp)))

    
    # # print(score_0,score_1,score_2,score_3,score_4,score_5)
    ii += 1
    # if ii == 80:
    #     break

    if class_ == 1:
        jj += 1

print(jj)
print(ii)
# Out:
# 1706
# 31332

# %%
#    other 

#      ，            ，               index，index/count_not_zero(sorted_word2tfidf)
def get_weight(sorted_word2tfidf,set,words):
    score = 0.0
    words = filter(words.split()).split()
    for word in words:
        if word in set:
            #  key word index
            index = 0
            for i in range(len(sorted_word2tfidf)):
                if sorted_word2tfidf[i][0] == word:
                    index = i
                    break
            # score += 100 * (count_not_zero(sorted_word2tfidf) / 3 - index) * sorted_word2tfidf[index][1]/(count_not_zero(sorted_word2tfidf) / 3)
            score += 100 * sorted_word2tfidf[index][1]
        else:
            score += 0
    return score
    
import csv
import math
#       



path6_v_i_t = "/home/user/lh/PMA_lihang/mypaper/data/1_3_aspects/AttType2_headTo_v_i_t.csv"
f6_v = open(path6_v_i_t, 'r')
lines6 = csv.reader(f6_v)

import numpy as np

max_right = 0
para0 = 0.1
para1 = 0.1
para2 = 0.1
para3 = 0.1
para4 = 0.1
para5 = 0.1

all_items = 78442+10690+3043+839+416+1166
ii = 0


for line in lines6:

    v6 = line[1]
    i6 = line[2]
    t6 = line[3]
    

    score_0 = para0 * (get_weight(sorted_word2tfidf0_v,set_v0,v6) * 5 + get_weight(sorted_word2tfidf0_i,set_i0,i6) * 4 + get_weight(sorted_word2tfidf0_t,set_t0,t6) * 3) 
    score_1 = para1 * (get_weight(sorted_word2tfidf1_v,set_v1,v6) * 5 + get_weight(sorted_word2tfidf1_i,set_i1,i6) * 4 + get_weight(sorted_word2tfidf1_t,set_t1,t6) * 3)
    score_2 = para2 * (get_weight(sorted_word2tfidf2_v,set_v2,v6) * 5 + get_weight(sorted_word2tfidf2_i,set_i2,i6) * 4 + get_weight(sorted_word2tfidf2_t,set_t2,t6) * 3)
    score_3 = para3 * (get_weight(sorted_word2tfidf3_v,set_v3,v6) * 5 + get_weight(sorted_word2tfidf3_i,set_i3,i6) * 4 + get_weight(sorted_word2tfidf3_t,set_t3,t6) * 3)
    score_4 = para4 * (get_weight(sorted_word2tfidf4_v,set_v4,v6) * 5 + get_weight(sorted_word2tfidf4_i,set_i4,i6) * 4 + get_weight(sorted_word2tfidf4_t,set_t4,t6) * 3)
    score_5 = para5 * (get_weight(sorted_word2tfidf5_v,set_v5,v6) * 5 + get_weight(sorted_word2tfidf5_i,set_i5,i6) * 4 + get_weight(sorted_word2tfidf5_t,set_t5,t6) * 3)

    list_temp = [score_0,score_1, score_2, score_3, score_4, score_5]
    class_ = list_temp.index(max(list_temp))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 54
#      52 score_0 = para0 * (get_weight(sorted_word2tfidf0_v,set_v0,v6) * 5 + get_weight(sorted_word2tfidf0_i,set_i0,i6) * 4 + get_weight(sorted_word2tfidf0_t,set_t0,t6) * 3)
#      53 score_1 = para1 * (get_weight(sorted_word2tfidf1_v,set_v1,v6) * 5 + get_weight(sorted_word2tfidf1_i,set_i1,i6) * 4 + get_weight(sorted_word2tfidf1_t,set_t1,t6) * 3)
# ---> 54 score_2 = para2 * (get_weight(sorted_word2tfidf2_v,set_v2,v6) * 5 + get_weight(sorted_word2tfidf2_i,set_i2,i6) * 4 + get_weight(sorted_word2tfidf2_t,set_t2,t6) * 3)
#      55 score_3 = para3 * (get_weight(sorted_word2tfidf3_v,set_v3,v6) * 5 + get_weight(sorted_word2tfidf3_i,set_i3,i6) * 4 + get_weight(sorted_word2tfidf3_t,set_t3,t6) * 3)
#      56 score_4 = para4 * (get_weight(sorted_word2tfidf4_v,set_v4,v6) * 5 + get_weight(sorted_word2tfidf4_i,set_i4,i6) * 4 + get_weight(sorted_word2tfidf4_t,set_t4,t6) * 3)
#
# NameError: name 'set_v2' is not defined
