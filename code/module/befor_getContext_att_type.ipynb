# %%
#  att_type  --      
import csv

#          ，        
path_data1 = "/home/user/Programs/PMA_lihang/data/pt1_file2_v2.csv"
path_data2 = "/home/user/Programs/PMA_lihang/data/pt2_file4_v2.csv"
path_data3 = "/home/user/Programs/PMA_lihang/data/pt3_file6_v2.csv"

f_data1 = open(path_data1, 'r', encoding='utf-8')
f_data2 = open(path_data2, 'r', encoding='utf-8')
f_data3 = open(path_data3, 'r', encoding='utf-8')

reader_data1 = csv.reader(f_data1)
reader_data2 = csv.reader(f_data2)
reader_data3 = csv.reader(f_data3)

# path_out = "/home/user/Programs/PMA_lihang/mypaper/data/1_3_aspects/dictForAttType_headTo_v_i_t.csv"
# path_out = "/home/user/Programs/PMA_lihang/mypaper/data/1_3_aspects/dictForImpact_headTo_vt_at_av.csv"
path_out = "/home/user/Programs/PMA_lihang/mypaper/data/1_3_aspects/dictForRootCause_headTo_vt_av_im.csv"
# path_out = "/home/user/Programs/PMA_lihang/mypaper/data/1_3_aspects/dictForVec_headTo_vt_rt_at.csv"
# path_out = "/home/user/Programs/PMA_lihang/mypaper/data/1_3_aspects/dictForV_type_headTo_rt_av_im.csv"
f_out = open(path_out, 'a')
writer = csv.writer(f_out)

dictForAttType_headTo_v_i_t = {}

for row in reader_data1:
    # dictForAttType_headTo_v_i_t[row[0]] = [row[4], row[3], row[6]]
    # dictForAttType_headTo_v_i_t[row[0]] = [row[6], row[2], row[4]]
    dictForAttType_headTo_v_i_t[row[0]] = [row[6], row[4], row[3]]
    # dictForAttType_headTo_v_i_t[row[0]] = [row[6], row[5], row[2]]
    # dictForAttType_headTo_v_i_t[row[0]] = [row[5], row[4], row[3]]
for row in reader_data2:
    dictForAttType_headTo_v_i_t[row[0]] = [row[6], row[4], row[3]]
for row in reader_data3:
    dictForAttType_headTo_v_i_t[row[0]] = [row[6], row[4], row[3]]

#    
for key in dictForAttType_headTo_v_i_t:# -》[v,i,t]
    writer.writerow([key, dictForAttType_headTo_v_i_t[key][0], dictForAttType_headTo_v_i_t[key][1], dictForAttType_headTo_v_i_t[key][2]])

# %%
# temp2  temp3

path_in = "/home/user/Programs/PMA_lihang/mypaper/module/temp2_root_cause.txt"
path_out = "/home/user/Programs/PMA_lihang/mypaper/module/temp3_root_cause.txt"

# path_in = "/home/user/Programs/PMA_lihang/mypaper/module/temp2_v_type.txt"
# path_out = "/home/user/Programs/PMA_lihang/mypaper/module/temp3_v_type.txt"

f_in = open(path_in, 'r', encoding='utf-8')
f_out = open(path_out, 'w', encoding='utf-8')

lines_in = f_in.readlines()

#      

# flag = True
# for i in lines_in:
#     # if "1 " in lines_in[i]:
#     #     flag = True
#     if "0 " in i:
#         flag = False
#         break
#     if flag:
#         f_out.write(i)

#     

flag = False
for i in lines_in:
    # if "1 " in lines_in[i]:
    #     flag = True
    if "10 " in i:
        flag = True
        continue
    if "11 " in i:
        flag = False
        break
    if flag:
        f_out.write(i)

# %%
#     （   ） head   ，      ,           head att_vec、impact、v_type

#  as

# path = "/home/user/Programs/PMA_lihang/mypaper/module/temp3.txt"#     aspect  
# path = "/home/user/Programs/PMA_lihang/mypaper/module/temp3_impact.txt"
path = "/home/user/Programs/PMA_lihang/mypaper/module/temp3_root_cause.txt"
# path = "/home/user/Programs/PMA_lihang/mypaper/module/temp3_vec.txt"
# path = "/home/user/Programs/PMA_lihang/mypaper/module/temp3_v_type.txt"
f = open(path, 'r')
lines = list(f.readlines())
#            
# path2 = "/home/user/Programs/PMA_lihang/mypaper/data/data_context_att_type.csv"
# path2 = "/home/user/Programs/PMA_lihang/mypaper/data/data_context_impact.csv"
path2 = "/home/user/Programs/PMA_lihang/mypaper/data/data_context_root_cause.csv"
# path2 = "/home/user/Programs/PMA_lihang/mypaper/data/data_context_att_vec.csv"
# path2 = "/home/user/Programs/PMA_lihang/mypaper/data/data_context_v_type.csv"
f2 = open(path2, 'r')
import csv
reader = list(csv.reader(f2))

att_n_aspect = [] #      aspect
att_n_head = [] #           ，        

for line in lines:
    att_n_aspect.append(line.strip())

for row in reader:
    aspect_now = row[1].strip()
    if aspect_now in att_n_aspect:
        att_n_head.append(row[0].strip())

# %%
#                  ，      

#     att_n_head     att_vec、impact、v_type,    
# path_dict = "/home/user/Programs/PMA_lihang/mypaper/data/1_3_aspects/dictForAttType_headTo_v_i_t.csv"
# f_dict = open(path_dict, 'r')
# reader_dict = csv.reader(f_dict)

#                  
# dictForAttType_headTo_v_i_t = {}
# for row in reader_dict:
#     head_now = row[0].strip()
#     v_i_t = []
#     v_i_t.append(row[1].strip())
#     v_i_t.append(row[2].strip())
#     v_i_t.append(row[3].strip())
#     dictForAttType_headTo_v_i_t[head_now] = v_i_t

#          


# path_useful = "/home/user/Programs/PMA_lihang/mypaper/data/1_3_aspects/AttType5_headTo_v_i_t.csv"
# path_useful = "/home/user/Programs/PMA_lihang/mypaper/data/1_3_aspects/Impact9_headTo_v_i_t.csv"
path_useful = "/home/user/Programs/PMA_lihang/mypaper/data/1_3_aspects/Root_cause11_headTo_vt_av_im.csv"
# path_useful = "/home/user/Programs/PMA_lihang/mypaper/data/1_3_aspects/Vec5_headTo_vt_rt_at.csv"
# path_useful = "/home/user/Programs/PMA_lihang/mypaper/data/1_3_aspects/V_type12_headTo_rt_av_im.csv"
f_useful = open(path_useful, 'a')
writer_useful = csv.writer(f_useful)

for head in att_n_head:
    #    
    writer_useful.writerow([head, dictForAttType_headTo_v_i_t[head][0], dictForAttType_headTo_v_i_t[head][1], dictForAttType_headTo_v_i_t[head][2]])

# %%
#  


#             head，  att type               ，          

path = "/home/user/Programs/PMA_lihang/mypaper/module/temp3.txt"#  0-5   aspect  
f = open(path, 'r')
lines = f.readlines()
#   
path2 = "/home/user/Programs/PMA_lihang/mypaper/data/data_context_att_type.csv"
f2 = open(path2, 'r')
import csv
reader = csv.reader(f2)

att_n_aspect = []
att_n_head = []

for line in lines:
    if "**" in line:
        continue
    att_n_aspect.append(line.strip())

for row in reader:
    aspect_now = row[1].strip()
    if aspect_now not in att_n_aspect: #             not in
        att_n_head.append(row[0].strip())

# %%
path_useful = "/home/user/Programs/PMA_lihang/mypaper/data/1_3_aspects/AttType6_headTo_v_i_t.csv"
f_useful = open(path_useful, 'a')
writer_useful = csv.writer(f_useful)

for head in att_n_head:
    #    
    writer_useful.writerow([head, dictForAttType_headTo_v_i_t[head][0], dictForAttType_headTo_v_i_t[head][1], dictForAttType_headTo_v_i_t[head][2]])
