# %%
#  gpt api         
import os
import openai
from tqdm import tqdm

prompt_head = '''
The original description is 
"Buffer overflow in Andreas Huggel Exiv2 before 0.9 does not null terminatestrings before calling the sscanf function, which allows remote attackers to cause a denial of service (application crash) via images with crafted IPTcmetadata.". 
I always extract 6 aspects from the original text according to the order of their appearance, namely Vulnerability Type, Root Cause, Affected Product, Impact, Attacker Type and Attack Vector. However, each of these aspects may not be present, and their order is not fixed.
The following are the results extracted from the original text: 
1. "Buffer overflow" is the Vulnerability Type.
2. "Andreas Huggel Exiv2 before 0.9" is the Affected Product.
3. "does not null terminatestrings before calling the sscanf function" is the Root Cause.
4. "remote attackers" is the Attacker Type.
5. "cause a denial of service (application crash)" is the Impact.
6. "via images with crafted IPTcmetadata" is the Attacker Vector.

The original description is 
"SQL injection vulnerability in the Cybozu Garoon 4.0.0 to 4.10.0 allows attacker with administrator rights to execute arbitrary SQL commands via the Log Search function of application 'logging'.".
I always extract 6 aspects from the original text according to the order of their appearance, namely Vulnerability Type, Root Cause, Affected Product, Impact, Attacker Type and Attack Vector. However, each of these aspects may not be present, and their order is not fixed.
The following are the results extracted from the original text: 
1. "SQL injection vulnerability" is the Vulnerability Type.
2. "Cybozu Garoon 4.0.0 to 4.10.0" is the Affected Product.
3. "attacker with administrator rights" is the Attacker Type.
4. "execute arbitrary SQL commands" is the Impact.
5. "via the Log Search function of application 'logging'" is the Attacker Vector. 
6. "" is the Root Cause.

The original description is 
"parse_audio_mixer_unit in sound/usb/mixer.c in the Linux kernel through 5.2.9 mishandles a short descriptor, leading to out-of-bounds memory access.".
I always extract 6 aspects from the original text according to the order of their appearance, namely Vulnerability Type, Root Cause, Affected Product, Impact, Attacker Type and Attack Vector. However, each of these aspects may not be present, and their order is not fixed.
The following are the results extracted from the original text: 
1. "parse_audio_mixer_unit in sound/usb/mixer.c in the Linux kernel through 5.2.9" is the Affected Product.
2. "mishandles a short descriptor" is the Root Cause.
3. "out-of-bounds memory access" is the Impact.
4. "" is the Vulnerability Type.
5. "" is the Attacker Type.
6. "" is the Attacker Vector. 

The original description is 
"MetadataExtractor 2.1.0 allows stack consumption.".
I always extract 6 aspects from the original text according to the order of their appearance, namely Vulnerability Type, Root Cause, Affected Product, Impact, Attacker Type and Attack Vector. However, each of these aspects may not be present, and their order is not fixed.
The following are the results extracted from the original text: 
1. "MetadataExtractor 2.1.0" is the Affected Product.
2. "stack consumption" is the Impact.
3. "" is the Root Cause.
4. "" is the Vulnerability Type.
5. "" is the Attacker Type.
6. "" is the Attacker Vector. 

The original description is
"'''

prompt_tail = '''".
I always extract 6 aspects from the original text according to the order of their appearance, namely Vulnerability Type, Root Cause, Affected Product, Impact, Attacker Type and Attack Vector. However, each of these aspects may not be present, and their order is not fixed.
The following are the results extracted from the original text:
'''

openai.api_key = "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"#"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"#
#           
path4 = "/home/user/Programs/PMA_lihang/data/allitems_v5.csv" 
path5 = "/home/user/Programs/PMA_lihang/data/allitems_v6_tail100.csv"
# data = []
i = 11

with open(path4, 'r', encoding = 'utf-8') as f:
  lines = f.readlines()
  for line in tqdm(lines):
    input = prompt_head + lines[len(lines)-i].split('\t##=divide=##\t')[1][:-1] + prompt_tail
    #data.append(input)
    #print("###\n",input,"\n#####")
    #print("input: ", input)
    # input = 'hello world'
    response = openai.Completion.create(
      model="text-davinci-003",
      prompt=input,
      max_tokens=2000,
      temperature=0.1,
      top_p=1,
      frequency_penalty=0.0,
      presence_penalty=0.0
      #stop=["
    )
    #print(response['choices'][0].text)
    output = response.choices[0].text
    #line   output
    line = lines[len(lines)-i].split('\t##=divide=##\t')[1][:-1] + output + '\n'
    #print(line, type(line))
    #data.append(line)
    #   data            
    
    with open(path5, 'a', encoding = 'utf-8') as f1:
      f1.writelines(line)

    i += 1
    if i == 100:
      break
    # print(i)
    # print(output)

# %%
s = "djcaod1houbdoua2 oahidn o   "
#              
import time
for i in range(10):
    #        ，      ，   except    
    try:
        #print(s.index('1'))
        print(1/0)
        #print(s.index('2'))
        #print(s.index('3'))
        #print(s.index('4'))
    except:
        print('error')
# Out:
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error

# %%
import openai
openai.api_key = "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"
head = "           ，"
des = ""
tail = "          : 0、remote attacker 1、Local attacker 2、authenticated user 3、Context dependent attacker 4、Physically proximate attacker 5、user-assisted attackers 6、unknow/unspecified attacker"
requirement = "          ，            。"
q = head + des + tail + requirement
q = "  ，   "
rsp = openai.ChatCompletion.create(
  model="gpt-3.5-turbo",
  messages=[
        {"role": "system", "content": " "},
        {"role": "user", "content": q}
    ]
)
ans = rsp.get("choices")[0]["message"]["content"]
print(ans)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     169             conn = connection.create_connection(
# --> 170                 (self._dns_host, self.port), self.timeout, **extra_kw
#     171             )
#
# /opt/conda/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# /opt/conda/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# TimeoutError: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#
# /opt/conda/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# /opt/conda/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# /opt/conda/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     352         # Add certificate verification
# --> 353         conn = self._new_conn()
#     354         hostname = self.host
#
# /opt/conda/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     181             raise NewConnectionError(
# --> 182                 self, "Failed to establish a new connection: %s" % e
#     183             )
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7feb2099b290>: Failed to establish a new connection: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# /opt/conda/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     795                 body_pos=body_pos,
# --> 796                 **response_kw
#     797             )
#
# /opt/conda/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     795                 body_pos=body_pos,
# --> 796                 **response_kw
#     797             )
#
# /opt/conda/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     755             retries = retries.increment(
# --> 756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     757             )
#
# /opt/conda/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPSConnectionPool(host='api.openai.com', port=443): Max retries exceeded with url: /v1/chat/completions (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7feb2099b290>: Failed to establish a new connection: [Errno 110] Connection timed out'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/openai/api_requestor.py in request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     523                 timeout=request_timeout if request_timeout else TIMEOUT_SECS,
# --> 524                 proxies=_thread_context.session.proxies,
#     525             )
#
# /opt/conda/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#
# /opt/conda/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#
# /opt/conda/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#
# ConnectionError: HTTPSConnectionPool(host='api.openai.com', port=443): Max retries exceeded with url: /v1/chat/completions (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7feb2099b290>: Failed to establish a new connection: [Errno 110] Connection timed out'))
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# /tmp/ipykernel_2229157/5742400.py in <module>
#      11   messages=[
#      12         {"role": "system", "content": " "},
# ---> 13         {"role": "user", "content": q}
#      14     ]
#      15 )
#
# ~/.local/lib/python3.7/site-packages/openai/api_resources/chat_completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# ~/.local/lib/python3.7/site-packages/openai/api_resources/abstract/engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     158             stream=stream,
#     159             request_id=request_id,
# --> 160             request_timeout=request_timeout,
#     161         )
#     162
#
# ~/.local/lib/python3.7/site-packages/openai/api_requestor.py in request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     222             stream=stream,
#     223             request_id=request_id,
# --> 224             request_timeout=request_timeout,
#     225         )
#     226         resp, got_stream = self._interpret_response(result, stream)
#
# ~/.local/lib/python3.7/site-packages/openai/api_requestor.py in request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     529             raise error.APIConnectionError(
#     530                 "Error communicating with OpenAI: {}".format(e)
# --> 531             ) from e
#     532         util.log_debug(
#     533             "OpenAI API response",
#
# APIConnectionError: Error communicating with OpenAI: HTTPSConnectionPool(host='api.openai.com', port=443): Max retries exceeded with url: /v1/chat/completions (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7feb2099b290>: Failed to establish a new connection: [Errno 110] Connection timed out'))

# %%
    forward   ，  LSTM        h_n   3   ，           ，     batch  ，           。
     h_n       ，          ，        [2,64,12]。          batch       ，          [batch_size, num_classes]。
  ，   h_n       ，        ，             。    `h_n = h_n[-1]`       ， h_n             。

        ：

```
class Text2norLstm(nn.Module):
    def __init__(self, vocab_size = 46795, embed_dim = 300, hidden_dim = 100, num_classes = 12):
        super(Text2norLstm, self).__init__()
        # create an embedding layer to map words to vectors
        self.embedding = nn.Embedding(vocab_size, embed_dim)
        # create a lstm layer to process the sequence of vectors
        self.lstm = nn.LSTM(embed_dim, hidden_dim, num_layers = 2, batch_first=True)
        # create a linear layer to map the final hidden state to the output logits
        self.linear = nn.Linear(hidden_dim , num_classes)
    
    def forward(self, x):
        
        print(x.shape)
        x = self.embedding(x)
        print(x.shape)
        
        _, (h_n, _) = self.lstm(x)
        print(h_n.shape)
        
        h_n = h_n[-1] # modify here
        print(h_n.shape)
        
        out = self.linear(h_n)
        print(out.shape)
        return out
```

# %%
import torch
import torch.nn as nn

class TextCNN(nn.Module):

    def __init__(self, vocab_size, embedding_dim, kernel_size, num_filters, output_dim, dropout):
        super().__init__()

        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.conv = nn.Conv1d(in_channels=embedding_dim,
                              out_channels=num_filters,
                              kernel_size=kernel_size)
        self.fc = nn.Linear(num_filters, output_dim)
        self.dropout = nn.Dropout(dropout)

    def forward(self, text):

        # text = [batch size, sent len]
        embedded = self.embedding(text)

        # embedded = [batch size, sent len, emb dim]
        embedded = embedded.permute(0, 2, 1)

        # embedded = [batch size, emb dim, sent len]
        conved = nn.functional.relu(self.conv(embedded))

        # conved = [batch size, num filters, sent len - kernel size + 1]
        pooled = nn.functional.max_pool1d(conved, conved.shape[2]).squeeze(2)

        # pooled = [batch size, num filters]
        dropped = self.dropout(pooled)
        return self.fc(dropped)

# %%
import openai

openai.api_key = "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"
url = []
try:
    response = openai.Image.create(
    #prompt="a white siamese cat",
    prompt='''
    The retreat-style B&B located in the forest has sloping sloping roofs and good lighting, which can be used for tourists to relax and blend well with the surrounding landscape
    ''',
    n=10,
    size="1024x1024"
    )

    for i in range(10):
      url.append(response['data'][i]['url'])
    
except openai.error.OpenAIError as e:
  print(e.http_status)
  print(e.error)
for i in range(10):
  print(i,"==="*20)
  print(url[i])
# Out:
# 0 ============================================================
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-filrjVy7ECPQGvKpcjxTRHID/user-Rik5RoCZmUjAQkx64cQq4H6d/img-SomuvbA6BshQ1mxYtx7sVemu.png?st=2023-02-24T06%3A18%3A39Z&se=2023-02-24T08%3A18%3A39Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-02-23T20%3A35%3A05Z&ske=2023-02-24T20%3A35%3A05Z&sks=b&skv=2021-08-06&sig=60eWWVq31oGoRt%2BzRjDGqMH0AYJ7LwfrfbgghloSo4c%3D
# 1 ============================================================
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-filrjVy7ECPQGvKpcjxTRHID/user-Rik5RoCZmUjAQkx64cQq4H6d/img-CgRnp7rY4jfP5NKgUuIwO1ZA.png?st=2023-02-24T06%3A18%3A39Z&se=2023-02-24T08%3A18%3A39Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-02-23T20%3A35%3A05Z&ske=2023-02-24T20%3A35%3A05Z&sks=b&skv=2021-08-06&sig=qpxD7FNoeMMLr8Q%2BhogO9FFdPPkLslb64TyAmqmM0oM%3D
# 2 ============================================================
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-filrjVy7ECPQGvKpcjxTRHID/user-Rik5RoCZmUjAQkx64cQq4H6d/img-WBt0xJKzdKHpDNYhQv71Ag3m.png?st=2023-02-24T06%3A18%3A39Z&se=2023-02-24T08%3A18%3A39Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-02-23T20%3A35%3A05Z&ske=2023-02-24T20%3A35%3A05Z&sks=b&skv=2021-08-06&sig=5kWGcUiNe9lD1bx7JzWUbi6Dl8LdkGb10VYyVIeQbsI%3D
# 3 ============================================================
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-filrjVy7ECPQGvKpcjxTRHID/user-Rik5RoCZmUjAQkx64cQq4H6d/img-xishvfZjhb7yDuGksjfeFMXR.png?st=2023-02-24T06%3A18%3A39Z&se=2023-02-24T08%3A18%3A39Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-02-23T20%3A35%3A05Z&ske=2023-02-24T20%3A35%3A05Z&sks=b&skv=2021-08-06&sig=M2XUp8IuVvrKhTFJelfe7/zrBRY1gPAwOCPtlrdmQ/A%3D
# 4 ============================================================
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-filrjVy7ECPQGvKpcjxTRHID/user-Rik5RoCZmUjAQkx64cQq4H6d/img-in62qVJrpJLla5OAqO4e5aBg.png?st=2023-02-24T06%3A18%3A39Z&se=2023-02-24T08%3A18%3A39Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-02-23T20%3A35%3A05Z&ske=2023-02-24T20%3A35%3A05Z&sks=b&skv=2021-08-06&sig=JXaSbU8RU7svDiiuJ/1Cz5Y627SLVkbv223ikR/jbho%3D
# 5 ============================================================
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-filrjVy7ECPQGvKpcjxTRHID/user-Rik5RoCZmUjAQkx64cQq4H6d/img-QJWjCi8n91uOrRaldmrYe6nl.png?st=2023-02-24T06%3A18%3A39Z&se=2023-02-24T08%3A18%3A39Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-02-23T20%3A35%3A05Z&ske=2023-02-24T20%3A35%3A05Z&sks=b&skv=2021-08-06&sig=BnydoqmwJhGjuWmMzHOkSvNGVLw9goyUKGT5zOv19NQ%3D
# 6 ============================================================
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-filrjVy7ECPQGvKpcjxTRHID/user-Rik5RoCZmUjAQkx64cQq4H6d/img-gIVHGkQAyZTEhnGAR051dDNW.png?st=2023-02-24T06%3A18%3A39Z&se=2023-02-24T08%3A18%3A39Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-02-23T20%3A35%3A05Z&ske=2023-02-24T20%3A35%3A05Z&sks=b&skv=2021-08-06&sig=fRVG77JbRv7XrCA6EAyDcJRXlETYLBc5YoQTCE6ARI0%3D
# 7 ============================================================
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-filrjVy7ECPQGvKpcjxTRHID/user-Rik5RoCZmUjAQkx64cQq4H6d/img-5AFCdKaciZUJTUrbsq46vWbV.png?st=2023-02-24T06%3A18%3A39Z&se=2023-02-24T08%3A18%3A39Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-02-23T20%3A35%3A05Z&ske=2023-02-24T20%3A35%3A05Z&sks=b&skv=2021-08-06&sig=xGMOlQHu7NuRvphzp0VnZQi68175KZMr186jWpt4Zoo%3D
# 8 ============================================================
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-filrjVy7ECPQGvKpcjxTRHID/user-Rik5RoCZmUjAQkx64cQq4H6d/img-ufjWT1zBNmdHuMkTfdabgKyh.png?st=2023-02-24T06%3A18%3A39Z&se=2023-02-24T08%3A18%3A39Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-02-23T20%3A35%3A05Z&ske=2023-02-24T20%3A35%3A05Z&sks=b&skv=2021-08-06&sig=WZEGr%2B1%2BZqEow5A0i0Rbcy4d2oJPA5jIJIffe41nlC0%3D
# 9 ============================================================
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-filrjVy7ECPQGvKpcjxTRHID/user-Rik5RoCZmUjAQkx64cQq4H6d/img-c4R5xTupuq4JMBkpqWuEpXhP.png?st=2023-02-24T06%3A18%3A39Z&se=2023-02-24T08%3A18%3A39Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-02-23T20%3A35%3A05Z&ske=2023-02-24T20%3A35%3A05Z&sks=b&skv=2021-08-06&sig=WzHpxg81F3DMvAOILJhb9yyayhaQMNBOYjxu%2BzHWpaY%3D

# %%
for i in range(10):
  print(i,"==="*20)
  print(url[i])

# %%
from PIL import Image

image=open("/home/user/Programs/PMA_lihang/code_lihang/prompt/image_edit_original.png", "rb")
mask=open("/home/user/Programs/PMA_lihang/code_lihang/prompt/image_edit_mask.png", "rb")
# if image.mode =='RGB':
#   image = image.convert('RGBA')
# if mask.mode =='RGB':
#   mask = mask.convert('RGBA')
url = []
response = openai.Image.create_edit(
  image=image,
  mask=mask,
  prompt='''
A sunny indoor lounge area with a swimming pool and a planet in the water, the top half is purple and the bottom half is green  
''',
  n=10,
  size="1024x1024"
)
for i in range(10):
  url.append(response['data'][i]['url'])
for i in range(10):
  print(i,"==="*20)
  print(url[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_477505/2148026935.py in <module>
#       8 #   mask = mask.convert('RGBA')
#       9 url = []
# ---> 10 response = openai.Image.create_edit(
#      11   image=image,
#      12   mask=mask,
#
# NameError: name 'openai' is not defined

# %%
url = []

response = openai.Image.create_variation(
  image=open("/home/user/Programs/PMA_lihang/code_lihang/prompt/image_edit_original.png", "rb"),
  n=10,
  size="1024x1024"
)
image_url = response['data'][0]['url']
for i in range(10):
  url.append(response['data'][i]['url'])
for i in range(10):
  print(i,"==="*20)
  print(url[i])
# Out:
# 0 ============================================================
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-filrjVy7ECPQGvKpcjxTRHID/user-Rik5RoCZmUjAQkx64cQq4H6d/img-DEeGX27C8P2ESlAAmlNDQbQX.png?st=2023-02-22T11%3A44%3A53Z&se=2023-02-22T13%3A44%3A53Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-02-21T21%3A55%3A16Z&ske=2023-02-22T21%3A55%3A16Z&sks=b&skv=2021-08-06&sig=2t9fYs%2BtHqSFGGRvgf2A1tD%2BgTnpYCUXW1fuSkEWoS8%3D
# 1 ============================================================
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-filrjVy7ECPQGvKpcjxTRHID/user-Rik5RoCZmUjAQkx64cQq4H6d/img-Xmiyrz1LiMX8B6Oo6zuokesj.png?st=2023-02-22T11%3A44%3A53Z&se=2023-02-22T13%3A44%3A53Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-02-21T21%3A55%3A16Z&ske=2023-02-22T21%3A55%3A16Z&sks=b&skv=2021-08-06&sig=AZDGPlOAH99wSYeiSij2rni9YF/s8yKE%2Bd3%2BCFpXzV0%3D
# 2 ============================================================
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-filrjVy7ECPQGvKpcjxTRHID/user-Rik5RoCZmUjAQkx64cQq4H6d/img-C6LqFi8hHs67x68LV7NefeRv.png?st=2023-02-22T11%3A44%3A53Z&se=2023-02-22T13%3A44%3A53Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-02-21T21%3A55%3A16Z&ske=2023-02-22T21%3A55%3A16Z&sks=b&skv=2021-08-06&sig=GGoy7MzSXpV%2BGVrGT5Mx%2BtrKhJfwjOx03Nl%2BPTMo9dE%3D
# 3 ============================================================
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-filrjVy7ECPQGvKpcjxTRHID/user-Rik5RoCZmUjAQkx64cQq4H6d/img-JRCrEfoLNZSbEQWfUxTsFlPa.png?st=2023-02-22T11%3A44%3A53Z&se=2023-02-22T13%3A44%3A53Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-02-21T21%3A55%3A16Z&ske=2023-02-22T21%3A55%3A16Z&sks=b&skv=2021-08-06&sig=NIsp9A3vYwk3D7pphT7CoccWs0i/0HyGOFL0yNMYv0U%3D
# 4 ============================================================
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-filrjVy7ECPQGvKpcjxTRHID/user-Rik5RoCZmUjAQkx64cQq4H6d/img-1laWQ3CI4eyOKkUgt7SQElWx.png?st=2023-02-22T11%3A44%3A53Z&se=2023-02-22T13%3A44%3A53Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-02-21T21%3A55%3A16Z&ske=2023-02-22T21%3A55%3A16Z&sks=b&skv=2021-08-06&sig=X1rmBf9YlvObdW1iyfyuB%2B/frASIGvTyxtJ/Qu7%2B5rI%3D
# 5 ============================================================
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-filrjVy7ECPQGvKpcjxTRHID/user-Rik5RoCZmUjAQkx64cQq4H6d/img-sLbS1NxwAKrGwphIFVI2Qzht.png?st=2023-02-22T11%3A44%3A53Z&se=2023-02-22T13%3A44%3A53Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-02-21T21%3A55%3A16Z&ske=2023-02-22T21%3A55%3A16Z&sks=b&skv=2021-08-06&sig=9I9eqzP6dQEaKB6QAVaaTSK8Pe5m1vgkutZxfgqTMBU%3D
# 6 ============================================================
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-filrjVy7ECPQGvKpcjxTRHID/user-Rik5RoCZmUjAQkx64cQq4H6d/img-mgDiyX5WWoBKq7zNhCNWt957.png?st=2023-02-22T11%3A44%3A53Z&se=2023-02-22T13%3A44%3A53Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-02-21T21%3A55%3A16Z&ske=2023-02-22T21%3A55%3A16Z&sks=b&skv=2021-08-06&sig=NC%2BW8fUzyNv6lX5z0sQS2q7Sl4GaOa6jYVaFjfkM9%2Bg%3D
# 7 ============================================================
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-filrjVy7ECPQGvKpcjxTRHID/user-Rik5RoCZmUjAQkx64cQq4H6d/img-OFbX6IA6CHVediOn9aKeD1Ft.png?st=2023-02-22T11%3A44%3A53Z&se=2023-02-22T13%3A44%3A53Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-02-21T21%3A55%3A16Z&ske=2023-02-22T21%3A55%3A16Z&sks=b&skv=2021-08-06&sig=ogmFap25yWI3Bx6IoaBOE12xDgEIl2xoU8pGTbxIUGs%3D
# 8 ============================================================
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-filrjVy7ECPQGvKpcjxTRHID/user-Rik5RoCZmUjAQkx64cQq4H6d/img-qh7DVn1P5jpDmv5DQEvoPKgl.png?st=2023-02-22T11%3A44%3A53Z&se=2023-02-22T13%3A44%3A53Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-02-21T21%3A55%3A16Z&ske=2023-02-22T21%3A55%3A16Z&sks=b&skv=2021-08-06&sig=wuPNWfFatXeQ9ARlc/8Tli7gAFh0LE6mgiQglPJAfoQ%3D
# 9 ============================================================
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-filrjVy7ECPQGvKpcjxTRHID/user-Rik5RoCZmUjAQkx64cQq4H6d/img-UfCooVKwpTnJCYwgdOEylnsB.png?st=2023-02-22T11%3A44%3A53Z&se=2023-02-22T13%3A44%3A53Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-02-21T21%3A55%3A16Z&ske=2023-02-22T21%3A55%3A16Z&sks=b&skv=2021-08-06&sig=x2jYqu2igJXptsF3qLnnfsPIHMCMIt4Kc1Nj1A6AoRI%3D
