# %%
#       ，        
#  tqdm 
from tqdm import tqdm
path = "/home/user/Programs/PMA_lihang/data/allitems.csv"
path1 = "/home/user/Programs/PMA_lihang/data/allitems_v2.csv"

# i = 0
# data = []
# with open(path, 'r', encoding = 'utf-8') as f:
#     lines = f.readlines()
#     for line in lines:
#         # i+=1
#         #               
#         if line.find('** RESERVED ** This candidate has been reserved by') != -1:
#             i+=1
#             continue
#         data.append(line)
#     #   data          
#     print(i)
#     with open(path1, 'w', encoding = 'utf-8') as f1:
#         f1.writelines(data)
path2 = "/home/user/Programs/PMA_lihang/data/allitems_v3.csv"
# i = 0
# data = []   
# with open(path1, 'r', encoding = 'utf-8') as f:
#     lines = f.readlines()
#     for line in lines:
#         # i+=1
#         #               
#         if line.find('** REJECT ** DO NOT USE THIS CANDIDATE NUMBER.') != -1:
#             i+=1
#             continue
#         data.append(line)
#     #   data          
#     print(i)
#     with open(path2, 'w', encoding = 'utf-8') as f1:
#         f1.writelines(data)
    
path3 = "/home/user/Programs/PMA_lihang/data/allitems_v4.csv"
# i = 0
# data = []   
# with open(path2, 'r', encoding = 'utf-8') as f:
#     lines = f.readlines()
#     for line in lines:
#         # i+=1
#         #               
#         if line.find('DO NOT USE THIS CANDIDATE NUMBER.') != -1:
#             i+=1
#             continue
#         data.append(line)
#     #   data          
#     print(i)
#     with open(path3, 'w', encoding = 'utf-8') as f1:
#         f1.writelines(data)        

#     
# data = []   
# m = 0
path4 = "/home/user/Programs/PMA_lihang/data/allitems_v5.csv"    
# with open(path3, 'r', encoding = 'utf-8') as f:
#     lines = f.readlines()
#     for line in tqdm(lines):
#         content = ''
#         #               
#         for i in range(len(line)):
#             if line[i] == ',':
#                 break
#             content += line[i]
        
#         content += '\t##=divide=##\t'
#         #     "ab" "kjl"     
#         for i in range(len(line)):
#             if line[i] == ',' and line[i+1] == '"':
#                 break
#         for j in range(i, len(line)):
#             if line[j] == '"' and line[j+1] == ',' and line[j+2] == '"':
#                 break
#         for k in range(i+2, j):
#             content += line[k]
#         content += '\n'
        
#         data.append(content)
        
# with open(path4, 'w', encoding = 'utf-8') as f1:
#     f1.writelines(data)

# %%
#       
path5 = "/home/user/Programs/PMA_lihang/data/allitems_v5.csv"
path5_cve_corpus = "/home/user/Programs/PMA_lihang/data/allitems_v5_cve_corpus.csv"


data = []
with open (path5, 'r', encoding = 'utf-8') as f:
    lines = f.readlines()
    for line in lines:
        data.append(line.split('\t##=divide=##\t')[1])
    
with open(path5_cve_corpus, 'w', encoding = 'utf-8') as f1:
    f1.writelines(data)

# %%
#       4      ，       
import os
import csv
#    
path_1 = '/home/user/Programs/PMA_lihang/data/pt1_file2_1.csv'
path_2 = '/home/user/Programs/PMA_lihang/data/pt2_file4.csv'
path_3 = '/home/user/Programs/PMA_lihang/data/pt3_file6.csv'
#    

# csv       

f1 = open(path_1, 'r', encoding = 'utf-8')
f2 = open(path_2, 'r', encoding = 'utf-8')
f3 = open(path_3, 'r', encoding = 'utf-8')
#          
lines1 = csv.reader(f1)
lines2 = csv.reader(f2)
lines3 = csv.reader(f3)

i = 0

data = []
for line in lines1:
    data.append(line)
for line in lines2:
    data.append(line)
for line in lines3:
    data.append(line)


# # for line in data:
# #     #line         
# #     print(len(line))
# #     break
#     if 7-line.count('') >= 5:
#         i+=1
#         data.append(line)
#     if line[5] != '':
#         print(line[5])
#         i += 1
    
#     if i ==30:
#         break
# Out:
# 7

# %%
#     root cause  
import os
import csv
#    
path_1 = '/home/user/Programs/PMA_lihang/data/pt1_file2_v2.csv'
path_2 = '/home/user/Programs/PMA_lihang/data/pt2_file4_v2.csv'
path_3 = '/home/user/Programs/PMA_lihang/data/pt3_file6_v2.csv'
#    

# csv       

f1 = open(path_1, 'r', encoding = 'utf-8')
f2 = open(path_2, 'r', encoding = 'utf-8')
f3 = open(path_3, 'r', encoding = 'utf-8')
#          
lines1 = csv.reader(f1)
lines2 = csv.reader(f2)
lines3 = csv.reader(f3)

i = 0

data = []
for line in lines1:
    data.append(line)
for line in lines2:
    data.append(line)
for line in lines3:
    data.append(line)


# # for line in data:
# #     #line         
# #     print(len(line))
# #     break
#     if 7-line.count('') >= 5:
#         i+=1
#         data.append(line)
#     if line[5] != '':
#         print(line[5])
#         i += 1
    
#     if i ==30:
#         break

# %%
print(data[0])
# Out:
# ['CVE-1999-0001', 'BSD-derived TCP/IP implementations ', 'remote attackers', 'cause a denial of service (crash or hang)', ' via crafted packets.', '', 'ip_input.c']

# %%
#  root_cause  

path_4 = '/home/user/Programs/PMA_lihang/data/data_root_cause_v2.csv'
mean_data = [1,2,3,4,6]

f4 = open(path_4, 'w', encoding = 'utf-8')
writer = csv.writer(f4)

def get_class(root_cause):
    #print("*******",i)
    # print(root_cause)
    # print("*"*50)
    if('input' in root_cause):
      #print("right")
      # list_content.append(0)
      return 0
    
    if('bound' in root_cause):
      #print(" 0")
      #print("right")
      return 1
    
    if('fail' in root_cause):
      return 2
    if( 'handle' in root_cause):
      return 2
    if('except' in root_cause):
      return 2
    
    if(  'design' in root_cause):
      return 3

    if(  'access' in root_cause):
      return 4
    
    if(  'atom' in root_cause):
      return 5
    
    if( 'race' in root_cause):
      return 6
    
    if(  'serial' in root_cause):
      return 7
    
    if( 'config' in root_cause):
      return 8
    
    if( 'origin' in root_cause):
      return 9
    
    if( 'environ' in root_cause):
      return 10
    
    return 11
kk = 0
for i in data:

    if 7-i[0:7].count('') >= 5:
      if i[5] != '':
          myData = []
          myData.append(i[0])
          context = ""
          for j in mean_data:
              context += i[j] + " "
          myData.append(context)
          root_cause = i[5]
          #   
          root_cause = root_cause.lower()
          class_ = get_class(root_cause)
          myData.append(class_)
          writer.writerow(myData)
